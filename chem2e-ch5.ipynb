# %% [markdown]
# ## OpenStax Chemistry, 2nd Ed. &ndash; Dean's Errata Submissions

# %% [markdown]
# ## Chapter 5

# %% [markdown]
# **Execute this cell to display chemical formulas.**
# It contains a LaTeX require for mhchem, which even applies to later cells.
# $ \require{mhchem} $

# %%
# from IPython.display import display, HTML
from decimal import *
from dp import *
sources = (b, i, c, n)
import pandas as pd
pd.set_option("display.float_format", str)
def compares(f):
    return pd.DataFrame({
        'b': f(b),
        'i': f(i),
        'n': f(n),
        'c': f(c)})

# %% [markdown]
# ### Chapter 5 - Formulas and Concepts

# %% [markdown]
# #### Chapter 5.1

# %% [markdown]
# $$ q_{substance\ a} + q_{substance\ b} = 0 $$
# $$ \text{specific heat}\  c = \frac{q}{m\Delta T} $$
# $$ \Delta T = T_{final} - T_{initial} = T_f - T_i $$
# $$
# \begin{align}
# q &= c \cdot m \cdot \Delta T \\
# &= c \cdot m \cdot (T_{final} - T_{initial}) \\
# &= m c \Delta T \quad \text{Can be pronounced m-cat}
# \end{align}
# $$
# $$ (c_a \cdot m_a \cdot \Delta T_a) + (c_b \cdot m_b \cdot \Delta T_b) = 0 $$
# $$ (c_a \cdot m_a \cdot (T_{a\ final} - T_{a\ initial})) + (c_b \cdot m_b \cdot (T_{b\ final} - T_{b\ initial})) = 0 $$
# $$ (c_a \cdot m_a \cdot (T_{a\ final} - T_{a\ initial})) = - (c_b \cdot m_b \cdot (T_{b\ final} - T_{b\ initial})) $$

# %% [markdown]
# #### Chapter 5.3

# %% [markdown]
# $$ \begin{align}
# q &:= \text{heat (heat flow into system is positive)} \\
# q_p &:= \text{heat under constant P} \\
# w &:= \text{work (work done on system is positive, by system is negative)} \\
# U &:= \text{internal energy} (\equiv E) \\
# P &:= \text{pressure} \\
# V &:= \text{volume} \\
# H &:= \text{enthalpy} \\
# \\
# \Delta U &= q + w \\
# H &= U + PV \text{ (unmeasurable)} \\
# \Delta H &= \Delta U + \Delta (PV) \text{ (measurable, negative for exothermic)} \\
# &= q + w + \Delta (PV) \\
# P \Delta V &= -w \\
# \Delta H &= \Delta U + P \Delta V \text{ (assuming constant P)} \\
# &= q_p + w + - w \\
# &= q_p \\
# \\
# 1\text{ bar} &= 0.987\text{ atm} \\
# \Delta H\degree &:= \text{Enthalpy change under standard conditions/standard state.} \\
# &\qquad\text{Book uses 1 atm and 298.15 K (25 $\degree$C), slightly different than IUPAC.} \\
# &\qquad\text{For solutions the standard conditions are 1 M molarity instead of 1 atm.} \\
# \Delta H\rlap\degree_c &:= \text{Standard enthalpy of combustion of 1 mol under standard conditions} \\
# \Delta H\rlap\degree_f &:= \text{Standard enthalpy of formation of 1 mol under standard conditions} \\
# &\qquad\text{This is formation of 1 mol of a substance from free elements.} \\
# \end{align} $$
#
# **Hess’s law:** If a process can be written as the sum of several stepwise processes, the enthalpy change of the total process equals the sum of the enthalpy changes of the various steps.
#
# If $n$ are the stoichiometric coefficients, then...
# $$ \begin{align}
# \Delta H \rlap \degree _{reaction} &=
#         \sum{n \cdot \Delta H \rlap \degree _f (\text{products})}
#         - \sum{n \cdot \Delta H \rlap \degree _f (\text{reactants})}
# \end{align} $$

# %% [markdown]
# ### Chapter 5 &ndash; Examples

# %% [markdown]
# #### Example 5.3 Solution

# %% [markdown]
# Define $a$ to be the metal, and $b$ to be the water.
# $$ T_{a\ final} - T_{a\ initial} = - \left(\frac{c_b \cdot m_b \cdot (T_{b\ final} - T_{b\ initial})}{c_a \cdot m_a}\right) $$
# $$ T_{a\ initial} = \left(\frac{c_b \cdot m_b \cdot (T_{b\ final} - T_{b\ initial})}{c_a \cdot m_a}\right) + T_{a\ final} $$
# $$ m_b = 425 g $$
# $$ c_b = 4.184 \frac{J}{g {\degree}C} $$
# $$ T_{b\ final} = 42.7 {\degree}C $$
# $$ T_{b\ initial} = 24.0 {\degree}C $$
# $$ m_a = 360.0 g $$
# $$ c_a = 0.449 \frac{J}{g {\degree}C} $$
# $$ T_{a\ final} = T_{b\ final} = 42.7 {\degree}C $$
# $$ T_{a\ initial} = \left(\frac{425 g \cdot 4.184 \frac{J}{g {\degree}C} \cdot (42.7 {\degree}C - 24.0 {\degree}C)}{360.0 g \cdot 0.449 \frac{J}{g {\degree}C}}\right) + 42.7 {\degree}C $$

# %%
((425 * 4.184 * (42.7 - 24.0)) / (360.0 * 0.449)) + 42.7
# Out:
# 248.41851026973524

# %% [markdown]
# $$ T_{a\ initial} = 248 {\degree}C $$

# %% [markdown]
# #### Example 5.3 Check Your Learning 1

# %% [markdown]
# $$ T_{a\ initial} = \left(\frac{c_b \cdot m_b \cdot (T_{b\ final} - T_{b\ initial})}{c_a \cdot m_a}\right) + T_{a\ final} $$

# %%
((4.184 * 390 * (39.9 - 22.6)) / (0.385 * 248))
# Out:
# 295.6582320904901

# %%
((4.184 * 390 * (39.9 - 22.6)) / (0.385 * 248)) + 39.9
# Out:
# 335.5582320904901

# %% [markdown]
# 336 degrees C

# %% [markdown]
# #### Example 5.3 Check Your Learning 2

# %% [markdown]
# $$ (c_a \cdot m_a \cdot (T_{a\ final} - T_{a\ initial})) = - (c_b \cdot m_b \cdot (T_{b\ final} - T_{b\ initial})) $$
# Define $a$ to be the metal, and $b$ to be the water.
# Note that $T_{a\ final}$ should always equal $T_{b\ final}$.
# $$ (c_a \cdot m_a \cdot (T_{final} - T_{a\ initial})) = - (c_b \cdot m_b \cdot (T_{final} - T_{b\ initial})) $$
# $$ \require{cancel} $$
# $$ \frac{\cancel{c_a \cdot m_a \cdot} (T_{final} - T_{a\ initial})}{\cancel{c_a \cdot m_a}(c_b \cdot m_b)} = - \frac{\cancel{c_b \cdot m_b \cdot} (T_{final} - T_{b\ initial})}{(c_a \cdot m_a)\cancel{c_b \cdot m_b}} $$
# $$ \frac{T_{final} - T_{a\ initial}}{c_b \cdot m_b} = - \frac{T_{final} - T_{b\ initial}}{c_a \cdot m_a} $$
# $$ \frac{T_{final}}{c_b \cdot m_b} - \frac{T_{a\ initial}}{c_b \cdot m_b} = - \frac{T_{final}}{c_a \cdot m_a} - \frac{T_{b\ initial}}{c_a \cdot m_a}$$

# %% [markdown]
# **Wait, back up**
# $$
# \begin{align}
# c_a \cdot m_a \cdot (T_{final} - T_{a\ initial}) &=
# - c_b \cdot m_b \cdot (T_{final} - T_{b\ initial})
# \\[1 ex]
# % c_a \cdot m_a \cdot T_{final} -
# % c_a \cdot m_a \cdot T_{a\ initial} &=
# % - c_b \cdot m_b \cdot T_{final} +
# % c_b \cdot m_b \cdot T_{b\ initial}
# % \\[1 ex]
# c_a \cdot m_a \cdot T_{final} -
# c_a \cdot m_a \cdot T_{a\ initial} &=
# c_b \cdot m_b \cdot T_{b\ initial} -
# c_b \cdot m_b \cdot T_{final}
# \\[1 ex]
# c_a \cdot m_a \cdot T_{final} +
# c_b \cdot m_b \cdot T_{final} &=
# c_b \cdot m_b \cdot T_{b\ initial} +
# c_a \cdot m_a \cdot T_{a\ initial}
# \\[1 ex]
# (c_a \cdot m_a + c_b \cdot m_b) \cdot T_{final} &=
# c_b \cdot m_b \cdot T_{b\ initial} +
# c_a \cdot m_a \cdot T_{a\ initial}
# \\[1 ex]
# T_{final} &=
# \frac{c_b \cdot m_b \cdot T_{b\ initial} + c_a \cdot m_a \cdot T_{a\ initial}}
#      {c_a \cdot m_a + c_b \cdot m_b}
# \end{align}
# $$

# %% [markdown]
# Defining $a$ to be the copper and $b$ to be the water, we have...
# $$
# T_{final} =
# \frac{4.184 J/g {\degree}C \cdot 390 g \cdot 22.6 {\degree}C +
#       0.385 J/g {\degree}C \cdot 248 g \cdot 314 {\degree}C}
#      {0.385 J/g {\degree}C \cdot 248 g + 4.184 J/g {\degree}C \cdot 390 g}
# $$

# %%
((4.184 * 390 * 22.6) + (0.385 * 248 * 314)) / ((0.385 * 248) + (4.184 * 390))
# Out:
# 38.70828373590237

# %% [markdown]
# 38.7 degrees C

# %% [markdown]
# #### Example 5.4 Solution

# %% [markdown]
# $$ \begin{align}
# \Delta T = T_{final} - T_{initial} &= T_f - T_i
# \\[1ex]
# c_{metal} \times m_{metal} \times \Delta T_{metal} &= -
# c_{water} \times m_{water} \times \Delta T_{water}
# \\[1 ex]
# c_{metal} &= - \frac{c_{water} \times m_{water} \times \Delta T_{water}}
#                     {m_{metal} \times \Delta T_{metal}}
# \\[1 ex]
# c_{metal} &= - \frac{4.184 J/g \degree C \times 60.0 g \times (28.5 - 22.0 \degree C)}
#                     {59.7 g \times (28.5 - 100.0 \degree C)}
# \end{align} $$

# %%
- (4.184 * 60.0 * (28.5 - 22.0)) / (59.7 * (28.5 - 100.0))
# Out:
# 0.3822750114207401

# %% [markdown]
# Specific heat $c_{metal} = 0.382 J / g \degree C$, so the metal is probably Copper.
#
# **<span style="color: red">Note:</span>** The book said 0.38 (and copper).  They had an interim step where (28.5 - 22.0) was reduced to (6.5).  I am guessing that explains why they rounded the answer to 2 significant digits.  I'm guessing that the rounding is arguable either way, because if you do the calculation all in one step you would round to 3 significant digits.

# %% [markdown]
# #### Example 5.4 Check Your Learning

# %%
- (4.184 * 75.0 * (29.7 - 24.0)) / (92.9 * (29.7 - 178.0))
# Out:
# 0.12982876620355413

# %% [markdown]
# Specific heat $c_{metal} = 0.130 J / g \degree C$ for the silvery-gray metal.
#
# The metal is probably lead, because the only other metal listed in Table 5.1 is gold, which does not have a silvery gray color.
#
# <strong style="color: red">Note:</strong>  The book said 0.13 (and lead).  I am guessing resolving the (29.7 - 24.0) term resulted in rounding to 2 significant digits.

# %% [markdown]
# #### Example 5.5 Solution

# %% [markdown]
# The book gives -2.9 kJ as the answer but assumes:
# - The density of the solutions are approximately the same as water, 1.0 g/mL
# - The specific heat of the solutions are approximately the same as water 4.184 J / g &deg;C
# - The calorimeter allows no heat to enter or leave.
# I want to try removing the first two assumptions, and see if I can calculate a more specific answer.  I will assume that the solutions are not being added to any additional water.
#
# So, the problem statement from the book is:
#
# > When 50.0 mL of 1.00 M HCl(aq) and 50.0 mL of 1.00 M NaOH(aq), both at 22.0 &deg;C, are added to a coffee cup calorimeter, the temperature of the mixture reaches a maximum of 28.9 &deg;C. What is the approximate amount of heat produced by this reaction?
#
# > $$ \ce{HCl(aq) + NaOH(aq) -> NaCl(aq) + H2O(l)} $$
#
# $$ 50.0\ mL * 1.00\ mol/L = .0500 L * 1.00 mol/L = 0.500 mol HCl $$
#
# <strong style="color:red">Wait.</strong> I do not know the density of aqueous solutions of HCl (a gas) or NaOH, nor do I know a good place to look them up, or calculate the densities at a particular molarity $M$.  I thought I could maybe calculate from the molar masses, but that does not help me with the densities.  Therefore, **nevermind**.

# %% [markdown]
# #### Example 5.5 Check Your Learning

# %% [markdown]
# When 100 mL of 0.200 M NaCl(aq) and 100 mL of 0.200 M AgNO<sub>3</sub>(aq), both at 21.9 °C, are mixed in a coffee cup calorimeter, the temperature increases to 23.5 °C as solid AgCl forms. How much heat is produced by this precipitation reaction? What assumptions did you make to determine your value?

# %%
-((100 + 100) * 1.0 * 4.184 * (23.5 - 21.9))
# Out:
# -1338.8800000000012

# %% [markdown]
# $$ q_{reaction} = - q_{solution} = -1.3 kJ $$
# We assumed that both input solutes were roughly the same density and specific heat as liquid water, and that the calorimeter did not absorb any heat or let any heat enter or escape.
#
# **<span style="color:red">Note:</span>** The book said 1.34 kJ, which differs from the rounding behavior used in the Example 5.5 Solution just above the Check Your Learning, so I will report it.

# %% [markdown]
# #### Example 5.6 Solution

# %%
-((3.21 + 50.0) * 4.184 * (20.3 - 24.9))
# Out:
# 1024.1009439999996

# %% [markdown]
# $$ \begin{align}
# q_{rxn} = - q_{soln} &= - (3.21 g\ \ce{NH4NO3} + 50.0 g\ \ce{H2O}) * 4.184 \frac{J}{g \degree C} * (20.3 \degree C - 24.9 \degree C) \\
# &= -(-1.02 kJ) \\[1 ex]
# &= 1.02kJ
# \end{align}$$
#
# The positive sign for $q_{reaction}$ means that heat has to be added to the reactants from the environment, making the reaction endothermic.  This assumes that the calorimeter does not provide or absorb heat or allow heat exchange with the outside environment.
#
# <strong style="color:red">Note:</strong> The book gave +1.0 kJ as the answer, but I think that is because they incorporated 20.3 - 24.9 = -4.6 first into the rounding.  I also forgot to mention the assumption that the final solution's specific heat is approximately the same as that of water.  (I also fat fingered the specific heat of water at first, but fixed that when I saw my answer disagreed greatly with the book answer.)

# %% [markdown]
# #### Example 5.6 Check Your Learning

# %%
-((300 + 3.00) * 4.184 * (-1.05))
# Out:
# 1331.1396

# %% [markdown]
# #### Example 5.7 Solution

# %% [markdown]
# The problem statement is:
# > When 3.12 g of glucose, $\ce{C6H12O6}$, is burned in a bomb calorimeter, the temperature of the calorimeter increases from 23.8 °C to 35.6 °C. The calorimeter contains 775 g of water, and the bomb itself has a heat capacity of 893 J/°C. How much heat was produced by the combustion of the glucose sample?
#
# First, let's determine the heat capacity $C_{sys}$ of the system as a whole.
# $$ \begin{align}
# C_{sys} &= C_{bomb} + C_{water} \\
# &= C_{bomb} + m_{water} \times c_{water} \\
# &= 893 J/\degree C + 775 g \times 4.184 J/g \degree C
# \end{align}$$
# Then multiply by temperature change $\Delta T$ to get the heat energy produced $q_{rel}$.
#
# $$ \begin{align}
# q_{rel} &= -q_{rxn} \\
# &= C_{sys} \times \Delta T \\
# &= (C_{bomb} + m_{water} \times c_{water}) \times (T_f - T_i) \\
# &= (893 J/\degree C + 775 g \times 4.184 J/g \degree C)
#     \times (35.6 \degree C - 23.8 \degree C)
# \end{align} $$

# %%
(893 + 775 * 4.184) * (35.6 - 23.8)
# Out:
# 48800.08000000001

# %% [markdown]
# The solution I get is
# $$ q_{rel} = 48.8 \times 10^3 J = 48.4 kJ $$
# The book did it in a little different order.
# $$ \begin{align}
# q_{rxn} &= -(q_{water} + q_{bomb}) \\
# &= -[4.184 \times 775 \times (35.6 - 23.8) + 893 \times (35.6 - 23.8)] \\
# &= -48.8 kJ
# \end{align} $$

# %%
-(4.184 * 775 * (35.6 - 23.8) + 893 * (35.6 - 23.8))
# Out:
# -48800.08

# %% [markdown]
# #### Example 5.7 Check Your Learning

# %%
(784 + 925 * 1 * 4.184) * 8.39
# Out:
# 39048.73800000001

# %% [markdown]
# $$ q_{rxn} = -39.0 kJ $$

# %% [markdown]
# #### Example 5.8 Solution

# %%
2.9 / 0.0500
# Out:
# 57.99999999999999

# %% [markdown]
# $ \text{The \textbf{thermochemical equation} is} $
# $$ \ce{HCl(aq) + NaOH(aq) -> NaCl(aq) + H2O(l)}\qquad \Delta H = -58 kJ $$

# %% [markdown]
# #### Example 5.8 Check Your Learning

# %%
display('Zn amus: ' + str(b.Zn))
mlzn = Decimal(1.34) / b.Zn
display('mlzn:    ' + str(mlzn))
display('dh 1mol: ' + str(Decimal('3.14') / mlzn))
display('---')
mlhcl = Decimal(60.0) / 10**3 * Decimal(0.750)
display('mlhcl:   ' + str(mlhcl))
display('dh 2mol: ' + str(Decimal('3.14') / mlhcl * 2))
# Out:
# 'Zn amus: 65.38'
# 'mlzn:    0.02049556439278066809324040644'
# 'dh 1mol: 153.2038805970149162339445892'
# '---'
# 'mlhcl:   0.0450'
# 'dh 2mol: 139.5555555555555555555555556'

# %% [markdown]
# The problem statement is
# > When 1.34 g Zn(s) reacts with 60.0 mL of 0.750 M HCl(aq), 3.14 kJ of heat are produced. Determine the enthalpy change per mole of zinc reacting for the reaction:
#
# $$ \ce{Zn(s) + 2HCl(aq) -> ZnCl2(aq) + H2(g)} $$
# $$ \begin{align}
# ml_{Zn} :&= \text{moles Zn tested} \\[1ex]
#     &= 1.34\text{ g Zn} \cdot
#         \frac{1\text{ mol Zn}}{65.38 \text{ g Zn}} \\[1ex]
#     &= 0.020496\text{ mol Zn} \\[1ex]
# \frac{\Delta H}{\text{1 mol Zn}} &= \frac{3.14\text{ kJ}}{ml_{Zn}} \\[1ex]
#     &= 153\text{ kJ} \\[1ex]
# ml_{HCl} :&= \text{moles HCl tested} \\[1ex]
#     &= 60.0\text{ mL} \cdot
#         \frac{1\text{ L}}{10^3\text{ mL}} \cdot
#         \frac{0.750\ \text{mol}\ \ce{HCl(aq)}}{1\text{ L}} \\[1ex]
#     &= 0.0450\text{ mol HCl (why not a multiple of $ml_{Zn}$?)} \\[1ex]
# \frac{\Delta H}{\text{2 mol HCl}} &=
#     \frac{3.14\text{ kJ}}{ml_{HCl}} \cdot
#     2\text{ mol} \\[1ex]
# &= 26.2\text{ kJ}
# \end{align} $$
#
# <strong style="color:red">Note:</strong> The book answer is $\Delta H = -153 \text{ kJ}$.  I don't know why calculating it from the HCl did not give the same answer as from Zn.

# %% [markdown]
# #### Example 5.9 Solution

# %%
def example5_9_sol(s):
    with localcontext(prec = 7):
        s_amu = s.C*12 + s.H*22 + s.O*11
        k_amu = s.K + s.Cl + s.O*3
        return {
            'Amus sucrose': s_amu,
            'Moles sucrose': Decimal('2.67') / s_amu,
            'Amus KClO3': k_amu,
            'Moles KClO3': Decimal('7.19') / k_amu,
            'Moles 8 KClO3': Decimal('7.19') / k_amu / 8,
            'Delta H': Decimal('43.7') / (Decimal('7.19') / k_amu / 8)
        }
example5_9_sol(b)
# Out:
# {'Amus sucrose': Decimal('342.296'),
#  'Moles sucrose': Decimal('0.007800266'),
#  'Amus KClO3': Decimal('122.55'),
#  'Moles KClO3': Decimal('0.05866993'),
#  'Moles 8 KClO3': Decimal('0.007333741'),
#  'Delta H': Decimal('5958.760')}

# %% [markdown]
# Problem statement:
# > A gummy bear contains 2.67 g sucrose, C12H22O11. When it reacts with 7.19 g potassium chlorate, KClO3, 43.7 kJ of heat are produced. Write a thermochemical equation for the reaction of one mole of sucrose:
# > $$ \ce{C12⁢H22⁢O11⁡(aq) + 8⁢KClO3⁢(aq)⟶12⁢CO2⁢(g) +11⁢H2O(𝑙) +8⁢KCl⁡(aq)} $$
#
# The book just said
# > Be sure to take both stoichiometry and limiting reactants into account...
#
# $$ \begin{align}
# \text{Moles }\ce{C12H22O11} &= 2.67 g \cdot \frac{1 mol}{342.296 g} \\
#     &= 0.007800\ mol \\
# \text{Moles }\ce{KClO3} &= 7.19 g \cdot \frac{1 mol}{122.55 g} \\
#     &= 0.05867\ mol \\
# \frac{0.05867\ mol}{8} &= 0.007334
# \end{align} $$
#
# $\ce{KClO3}$ is the limiting reactant.  Although 0.007800 Moles of sucrose are available to react, only 0.007334 Moles actually reacted due to the limited amount of potassium chlorate.
#
# $$ \begin{align}
# \Delta H &= - \frac{43.7\ kJ}{0.007334\ mol} \\[1 ex]
#     &= 5.96 \times 10^3\ kJ = 5.96 \times 10^6\ J
# \end{align} $$
#
# $$ \ce{C12⁢H22⁢O11⁡(aq) + 8⁢KClO3⁢(aq)⟶12⁢CO2⁢(g) +11⁢H2O(𝑙) +8⁢KCl⁡(aq)} \quad \Delta H = - 5.96 \times 10^6\ J$$

# %% [markdown]
# #### Example 5.9 Check Your Learning

# %%
def example5_9_check(s):
    with localcontext(prec = 7):
        amu_fe = s.Fe
        mol_fe = Decimal('1.42') / amu_fe
        mol_fe_round = round(mol_fe, 4)
        amu_cl = s.Cl*2
        mol_cl = Decimal('1.80') / amu_cl
        mol_cl_round = round(mol_cl, 4)
        return {
            'Fe amu': amu_fe,
            'Cl2 amu': amu_cl,
            'Fe mol ': mol_fe,
            'Cl2 mol': mol_cl,
            'Fe round': mol_fe_round,
            'Cl2 round': mol_cl_round,
            'Delta H': Decimal(8.60) / mol_cl,
            'Delta H Fe': Decimal(8.60) / mol_fe,
            'Delta H round': Decimal(8.60) / mol_cl_round,
            'Delta H round Fe': Decimal(8.60) / mol_fe_round,
        }
example5_9_check(b)
# Out:
# {'Fe amu': Decimal('55.85'),
#  'Cl2 amu': Decimal('70.90'),
#  'Fe mol ': Decimal('0.02542525'),
#  'Cl2 mol': Decimal('0.02538787'),
#  'Fe round': Decimal('0.0254'),
#  'Cl2 round': Decimal('0.0254'),
#  'Delta H': Decimal('338.7444'),
#  'Delta H Fe': Decimal('338.2464'),
#  'Delta H round': Decimal('338.5827'),
#  'Delta H round Fe': Decimal('338.5827')}

# %%
compares(example5_9_check)
# Out:
#                            b           i           n           c
# Fe amu                 55.85      55.845       55.84      55.845
# Cl2 amu                70.90       70.90       70.90       70.90
# Fe mol            0.02542525  0.02542752  0.02542980  0.02542752
# Cl2 mol           0.02538787  0.02538787  0.02538787  0.02538787
# Fe round              0.0254      0.0254      0.0254      0.0254
# Cl2 round             0.0254      0.0254      0.0254      0.0254
# Delta H             338.7444    338.7444    338.7444    338.7444
# Delta H Fe          338.2464    338.2162    338.1859    338.2162
# Delta H round       338.5827    338.5827    338.5827    338.5827
# Delta H round Fe    338.5827    338.5827    338.5827    338.5827

# %% [markdown]
# Problem statement:
# > When 1.42 g of iron reacts with 1.80 g of chlorine, 3.22 g of FeCl2(s) and 8.60 kJ of heat is produced. What is the enthalpy change for the reaction when 1 mole of FeCl2(s) is produced?
#
# First, write a balanced equation:
# $$ \ce{Fe(s) + Cl2(g) -> FeCl2(s)} $$
#
# In the code section above, we determine that $\ce{Cl2}$ is the limiting reactant.  Therefore:
# $$ \begin{align}
# \Delta H &= - \frac{8.60\ kJ}{0.02539\ mol} \\[1ex]
#     &= - 339\ kJ
# \end{align} $$
#
# <strong style="color:red">Note: </strong> The book answer is -338 kJ, which I can only account for using Fe as the limiting reactant, which every atomic weight source I tried agreed is wrong.  I cannot account for the different answer with different atomic weight sources.  Nor can I account for the different answer with rounding.
#
# **TODO: ### Re-examine, and if I cannot get the book answer, report it as a possible issue.**

# %% [markdown]
# #### Example 5.10 Solution

# %%
def example5_10_sol(s):
    with localcontext(prec = 7):
        io_amu = s.C*8 + s.H*18
        io_amu_round = round(io_amu, 2)
        return {
            'amu isooctane': io_amu,
            'delta h': 1 * 10**3 * Decimal('0.692') / io_amu * Decimal('-5465.5'),
            'delta h -5460': 1 * 10**3 * Decimal('0.692') / io_amu * Decimal('-5460'),
            'amu rounded': io_amu_round,
            'delta h rounded': 1 * 10**3 * Decimal('0.692') / io_amu_round * Decimal('-5465.5'),
            'delta h -5460 rounded': 1 * 10**3 * Decimal('0.692') / io_amu_round * Decimal('-5460'),
            'mol isooctane': 1 * 10**3 * Decimal('0.692') / io_amu,
            'mol isooctane rounded': 1 * 10**3 * Decimal('0.692') / io_amu_round,
            'bad intermediate moles': Decimal('6.07') * Decimal('-5465.5'),
            'bad intermediate moles -5460': Decimal('6.07') * Decimal('-5460'),
        }
compares(example5_10_sol)
# Out:
#                                       b          i          n          c
# amu isooctane                   114.224   114.2320   114.2320    114.232
# delta h                       -33111.48  -33109.16  -33109.16  -33109.16
# delta h -5460                 -33078.16  -33075.84  -33075.84  -33075.84
# amu rounded                      114.22     114.23     114.23     114.23
# delta h rounded               -33112.64  -33109.74  -33109.74  -33109.74
# delta h -5460 rounded         -33079.32  -33076.42  -33076.42  -33076.42
# mol isooctane                  6.058271   6.057847   6.057847   6.057847
# mol isooctane rounded          6.058484   6.057953   6.057953   6.057953
# bad intermediate moles        -33175.58  -33175.58  -33175.58  -33175.58
# bad intermediate moles -5460  -33142.20  -33142.20  -33142.20  -33142.20

# %% [markdown]
# The problem statement is:
# > Let us determine the approximate amount of heat produced by burning 1.00 L of gasoline, assuming the enthalpy of combustion of gasoline is the same as that of isooctane, a common component of gasoline. The density of isooctane is 0.692 g/mL.
#
# From Table 5.2, isooctane's enthalpy of combustion is –5465.5 kJ/mol and the formula for isooctane is $\ce{C8H18}$.
#
# $$ \begin{align}
# \Delta H\rlap\degree_{c\ isooctane} &= –5465.5\ kJ/mol \\
# \Delta H &= 1.00\ L
#         \cdot \frac{10^3\ mL}{1\ L}
#         \cdot \frac{0.692\ g}{1\ mL}
#         \cdot \frac{1\ mol}{114.224\ g}
#         \cdot \frac{-5465.5\ kJ}{1\ mol}
#         \\
#     &= -3.31 \times 10^4\ kJ = -33100\ kJ \\
# \text{Heat produced} &= -\Delta H \\
#     &= 33100\ kJ
# \end{align} $$
#
# <strong style="color:red">Note:</strong> The book gets two things wrong.
# - It uses an incorrect enthalpy of combustion for isooctane which does not match Table 5.2 as claimed.
# - It has a wrong intermediate result for the number of moles of isooctane.
# If you fix both issues, the final answer, when rounded, is unchanged.

# %% [markdown]
# #### Example 5.10 Check Your Learning

# %%
def example5_10_check(s):
    with localcontext(prec = 7):
        amu_ac = s.C*2 + s.H*2
        return {
            'amu acetylene': amu_ac,
            'Delta H': Decimal('125') / amu_ac * Decimal('-1301.1'),
        }
example5_10_check(b)
# Out:
# {'amu acetylene': Decimal('26.036'), 'Delta H': Decimal('-6246.640')}

# %% [markdown]
# Problem statement:
# > How much heat is produced by the combustion of 125 g of acetylene?
#
# From Table 5.2 the formula for Acetylene is $\ce{C2H2(g)}$, and its enthalpy of combustion is -1301.1 kJ/mol.
#
# $$ \begin{align}
# \Delta H \rlap{\degree} _{c\ acetylene} &= -1301.1\ kJ/mol \\
# \Delta H &= 125\ g\ \ce{C2H2}
#         \cdot \frac{1\ mol\ \ce{C2H2}}{26.036\ g}
#         \cdot \frac{-1301.1\ kJ}{1\ mol\ \ce{C2H2}} \\
#     &= -6250\ kJ \\
# \text{Heat produced} &= - \Delta H \\
#     &= 6250\ kJ \\
# \end{align} $$

# %% [markdown]
# #### Example 5.11 Solution

# %%
+286 / 2
# Out:
# 143.0

# %% [markdown]
# $$ \Delta H \rlap \degree _f [\ce{O3(g)}]= + 143\ kJ/mol$$

# %% [markdown]
# #### Example 5.11 Check Your Learning

# %%
-92.3 * 2
# Out:
# -184.6

# %% [markdown]
# $$ \Delta H = -184.6\ kJ $$
# **Oops:** I divided by 2 instead of multiplied at first.  My bad.

# %% [markdown]
# #### Example 5.12 Solution

# %% [markdown]
# Problem statement:
# > Write the heat of formation reaction equations for:
# >
# > (a) $\ce{C2H5OH(l)}$
# >
# > (b) $\ce{Ca3(PO4)2(s)}$
#
# $ \ce{2C(s, graphite) + 3H2(g) + \frac12O2(g) -> C2H5OH(l)} $
#
# $ \ce{3Ca(s) + \frac12P4(s) + 4O2(g) -> Ca3(PO4)2(s)} $
#
# **Note:** I didn't know I could add ", graphite" to the solid indicator for carbon until I saw the book answer.  Also, the 0 enthalpy of formation entries in Appendix G were useful for knowning the stable pure states of elements.

# %% [markdown]
# #### Example 5.12 Check Your Learning

# %% [markdown]
# Problem statement:
# > Write the heat of formation reaction equations for:
# >
# > (a) $\ce{C2H5OC2H5(l)}$
# >
# > (b) $\ce{Na2CO3(s)}$
#
# $\ce{4C(s, graphite) + 5H2(g) + \frac12 O2(g) -> C2H5OC2H5(l)}$
#
# $\ce{Na(s) + C(s, graphite) + \frac32 O2(g) -> Na2CO3(s)}$
#
# **Oops:** Put 2 Carbon atoms as input instead of one.

# %% [markdown]
# #### Example 5.13 Solution

# %%
-341.8 + - 57.7
# Out:
# -399.5

# %% [markdown]
# #### Example 5.13 Check Your Learning

# %%
display(-57.06 * 2)
display(180.5 - 114.12)
# Out:
# -114.12
# 66.38

# %% [markdown]
# It is asking for the $\Delta H$ of this process that gives 2 moles, not the enthalpy of formation per mole $\Delta H \rlap \degree _f$.  Therefore, we do not need to first put the overall equation in a form resulting in a single mole of product.
# $$ \ce{N2(g) + 2 O2(g) -> 2 NO2(g)} $$
# However, we do need to put the constituant reactions in forms that add up to the overall equation.
# $$ \ce{N2(g) + O2(g) -> 2NO(g)} \qquad \Delta H = 180.5\ kJ $$
# $$ \ce{2NO(g) + O2(g) -> 2NO2(g)} \qquad \Delta H = -114.12\ kJ $$
# Summing those gives:
# $$ \Delta H = 66.4\ kJ $$

# %% [markdown]
# #### Example 5.14 Solution

# %% [markdown]
# Find the $\Delta H_{(i)}$ for the top equation using the remaining equations with known $\Delta H$:
#
# $$ \begin{align}
# (i)& &&\ce{ClF⁡(g) +F2⁡(g) &&-> ClF3⁢(g)} \qquad
#     &&\Delta H \rlap \degree _{(i)} &&= ? \\[1ex]
# (ii)& &&\ce{2⁢OF2⁢(g) &&->O2⁡(g) +2⁢F2⁡(g)} \qquad
#     &&\Delta H \rlap \degree _{(ii)} &&= -49.4\ kJ \\[1ex]
# (iii)& &&\ce{2⁢ClF⁡(g) +O2⁡(g) &&->Cl2O(g) +OF2⁢(g)} \qquad
#     &&\Delta H \rlap \degree _{(iii)} &&= + 214.0\ kJ \\
# (iv)& &&\ce{ClF3⁢(g) +O2⁡(g) &&->\frac12 ⁢Cl2O(g) + \frac32 ⁢OF2⁢(g)} \qquad
#     &&\Delta H \rlap \degree _{(iv)} &&= +236.2\ kJ \\[1ex]
# \end{align} $$

# %%
display(-49.4 / -2)
display(+214.0 / 2)
display(+236.2 * -1)
display(24.7 + 107.0)
display(131.7 - 236.2)
# Out:
# 24.7
# 107.0
# -236.2
# 131.7
# -104.5

# %% [markdown]
# To get from reactants to final product, I need:
# - Equation (ii) backward and halved.
# - Equation (iii) halved.
# - Equation (iv) backward.
# $$ \begin{alignat}{4}
# (i)&\quad&&\ce{ClF⁡(g) +F2⁡(g) &&-> ClF3⁢(g)} \qquad
#     &&\Delta H \degree &&= ? \\[1ex]
# (ii)& &&\ce{\frac12 O2⁡(g) +⁢F2⁡(g) &&-> ⁢OF2⁢(g)} \qquad
#     &&\Delta H \degree &&= +24.7\ kJ \\
# (iii)& &&\ce{⁢ClF⁡(g) +\frac12 O2⁡(g) &&->\frac12 Cl2O(g) +\frac12 OF2⁢(g)} \qquad
#     &&\Delta H \degree &&= + 107.0\ kJ \\
# (iv)& &&\ce{\frac12 ⁢Cl2O(g) + \frac32 ⁢OF2⁢(g) &&->ClF3⁢(g) +O2⁡(g)} \qquad
#     &&\Delta H \degree &&= -236.2\ kJ \\[1ex]
# \end{alignat} $$

# %% [markdown]
# Summing equations (ii) and (iii) gives:
# $$ \begin{alignat}{3}
# &\ce{ClF⁡(g)  + ⁢F2⁡(g) + O2⁡(g)
#     &&-> ⁢\frac12 Cl2O(g) +\frac32 OF2⁢(g)} \qquad
#     &&\Delta H \rlap \degree _{(ii)} &&= +131.7\ kJ \\
# \end{alignat} $$

# %% [markdown]
# Summing equation (iv) onto the previous result gives:
# $$ \begin{alignat}{3}
# &\ce{ClF⁡(g) + ⁢F2⁡(g) + O2⁡(g) &&-> ClF3⁢(g) + O2⁡(g)} \qquad
#     &&\Delta H \rlap \degree _{(ii)} &&= -104.5\ kJ \\
# \end{alignat} $$
# Which simplifies to equation (i) and thus gives us our answer:
# $$ \begin{alignat}{3}
# &\ce{ClF⁡(g) + ⁢F2⁡(g) &&-> ClF3⁢(g)} \qquad
#     &&\Delta H \rlap \degree _{(ii)} &&= -104.5\ kJ \\
# \end{alignat} $$

# %% [markdown]
# #### Example 5.14 Check Your Learning

# %% [markdown]
# Calculate $\Delta H \degree$ of equation (i) from the remaining equations:
# $$ \begin{alignat}{4}
# (i)&\quad&&\ce{2⁢Al⁡(s) +3⁢Cl2⁢(g) && ->2⁢AlCl3⁢(s)} \qquad
#     &&\Delta H \degree &&= ? \\
# (ii)& &&\ce{HCl⁡(g) &&->HCl⁡(aq)} \qquad
#     &&\Delta H \degree &&= -74.8\ kJ \\
# (iii)& &&\ce{H2⁡(g) +Cl2⁢(g) &&->2⁢HCl⁡(g)} \qquad
#     &&\Delta H \degree &&= -185\ kJ \\
# (iv)& &&\ce{AlCl3⁢(aq) &&->AlCl3⁢(s)} \qquad
#     &&\Delta H \degree &&= +323\ kJ \\
# (v)& &&\ce{2Al⁡(s) +6⁢HCl⁡(aq) &&->2⁢AlCl3⁢(aq) +3⁢H2⁡(g)} \qquad
#     &&\Delta H \degree &&= -1049\ kJ \\
# \end{alignat} $$

# %%
(3 * -185) + (6 * -74.8) + -1049 + (2 * 323)
# Out:
# -1406.8000000000002

# %% [markdown]
# To get equation (i) I need to do:
# $$ 3 \cdot (iii) + 6 \cdot (ii) + (v) + 2 \cdot (iv) = (i) $$
# Therefore:
# $$ \Delta H \rlap \degree _{(i)} = -1407\ kJ $$

# %% [markdown]
# #### Exercise 5.15 Solution

# %%
2 * -207.4 + 90.25 - (3 * 33.2 - 285.83)
# Out:
# -138.32000000000005

# %% [markdown]
# Problem statement:
# > What is the standard enthalpy change for the reaction:
# > $$ \ce{3⁢NO2⁢(g) +H2O(l) -> 2⁢HNO3⁢(aq) +NO⁡(g)} \qquad \Delta H \degree =\ ? $$
#
# From appendix G:
# | Substance | Standard Enthalpy of Formation $ \Delta H \rlap \degree _f\ kJ/mol $ |
# | - | - |
# | $\ce{NO2(g)}$ | 33.2 |
# | $\ce{H2O(l)}$ | -285.83 |
# | $\ce{HNO3(aq)}$ | -207.4 |
# | $\ce{NO(g)}$ | 90.25 |
#
# So
# $$ \Delta H \rlap \degree _{\text{reaction}} = -138.3\ kJ $$

# %%
display(3 * 33.2)
display(2 * -207.4)
display(-99.6 + 285.83 - 414.8 + 90.25)
display(-99.6 + 285.8 - 414.8 + 90.2)
# Out:
# 99.60000000000001
# -414.8
# -138.32000000000002
# -138.39999999999998

# %% [markdown]
# #### Exercise 5.15 Check Your Learning

# %%
dh_ethanol = -278
dh_H2O = -286
dh_CO2 = -394
dh_O2 = 0
2*dh_CO2 + 3*dh_H2O - (dh_ethanol + 3*dh_O2)
# Out:
# -1368

# %% [markdown]
# The combustion formula for ethanol is:
# $$ \ce{C2H5OH(l) + 3 O2(g) -> 2 CO2(g) + 3 H2O(l)} $$
# The $\Delta H \rlap \degree _c $ is:
# $$ \Delta H \rlap \degree _c = -1368\ kJ/mol $$
# **Note:** I didn't originally express the answer as per mole.

# %% [markdown]
# ### Chapter 5 &ndash; Exercises

# %% [markdown]
# #### Ex 5.1
#
# While the temperature (an intensive property) of a lit match is high,
# the match is small.  Therefore, the total amount of thermal energy it
# contains (an extensive property) is small, and the amount of heat flow
# it is giving off to you and its environment is small,
# making it a poor choice to heat something as big as a person.

# %% [markdown]
# #### Ex 5.3
#
# The specific heat (c) of a substance is the amount of heat energy required to change the temperature of 1 gram of the substance by 1 &deg;C.  Since it is per unit mass, it does not depend on the amount of the substance and is an intensive property.
#
# The heat capacity of something is the amount of heat energy required to change the temperature of something by 1 &deg;C.  Since it depends on the amount of the substance, it is an extensive property.

# %% [markdown]
# #### Ex 5.5

# %%
CNJ = 45.8 * 1.040
CAlJ = 1 / 2.205 * 1000 * 0.897
CAlJexact = 1 * 0.4535924 * 1000 * 0.897
CAlJapprox = 1 / 2.2 * 1000 * 0.897
CAlJgrams = 1 * 464 * 0.897
display(CNJ)
display(CNJ / 4.184)
display(CAlJ)
display(CAlJ / 4.184)
display(CAlJexact)
display(CAlJexact / 4.184)
display(CAlJapprox)
display(CAlJapprox / 4.184)
display(CAlJgrams)
display(CAlJgrams / 4.184)
# Out:
# 47.632
# 11.384321223709367
# 406.8027210884353
# 97.22818381654763
# 406.8723828
# 97.24483336520076
# 407.7272727272727
# 97.44915696158525
# 416.208
# 99.47609942638624

# %% [markdown]
# Calculate the heat capacity, in joules and in calories per degree, of the following:
#
# (a) 45.8 g of nitrogen gas
#
# (b) 1.00 pound of aluminum metal
#
# $$ \begin{align}
# c &:= \frac{J}{g \degree C} \\
# C &= m \cdot c \text{ in } \frac{J}{\degree C} \\
# C_N &= 47.6\ J/\degree C = 11.4\ cal/\degree C \\[1ex]
# C_{Al} &= 407\ J/\degree C = 97.2\ cal/\degree C \\
# \end{align} $$
#
# **Note:** Two of the book answers were slightly different, but I'm pretty sure the book is wrong.  I am reporting them as errata.

# %% [markdown]
# #### Ex 5.7

# %%
qJ = 28.4 * 2.093 * (-1.0 - -23.0)
qc = qJ / 4.184
display(qJ)
display(qc)
# Out:
# 1307.7063999999998
# 312.54933078393873

# %% [markdown]
# $$ 1.31 \times 10^3\ J, 313\ cal $$

# %% [markdown]
# #### Ex5.9
# $$ q = mc\Delta T $$
# $$ \Delta T = \frac{q}{mc} $$

# %%
14.5 * 10**3 / (485 * 4.184)
# Out:
# 7.145532317517889

# %% [markdown]
# #### Ex 5.11
# $$ q = mc \Delta T $$
# $$ c = \frac{q}{m \Delta T} $$

# %%
8460 / (437.2 * (68.9 - 19.3))
# Out:
# 0.3901292683646666

# %% [markdown]
# $$ c_{substance} = 0.390\ J/g \degree C $$
# The substance is probably copper.

# %% [markdown]
# #### Ex 5.13
#
# Most people find waterbeds uncomfortable unless the water temperature is maintained at about 85 °F. Unless it is heated, a waterbed that contains 892 L of water cools from 85 °F to 72 °F in 24 hours. Estimate the amount of electrical energy required over 24 hours, in kWh, to keep the bed from cooling. Note that 1 kilowatt-hour (kWh) = 3.6 × 10<sup>6</sup> J, and assume that the density of water is 1.0 g/mL (independent of temperature). What other assumptions did you make? How did they affect your calculated result (i.e., were they likely to yield “positive” or “negative” errors)?

# %%
tiC = (85 - 32) / 9 * 5
tfC = (72 - 32) / 9 * 5
dtC = tfC - tiC
display(f'Init: {tiC} C, Final: {tfC} C, Delta: {dtC}')
mbed = 892 * 10**3 * 1.0
Cbed = mbed * 4.184
display(f'm bed: {mbed} g, C bed: {Cbed} J/C')
qJ = Cbed * dtC
qkWh = qJ / (3.6 * 10**6)
display(f'q:{qJ} J, {qkWh} kWh')
onestep = - (((72 - 32) / 9 * 5) - ((85 - 32) / 9 * 5)) * 892 * 10**3 * 1.0 * 4.184 / (3.6 * 10**6)
display(onestep)
# Out:
# 'Init: 29.444444444444446 C, Final: 22.22222222222222 C, Delta: -7.222222222222225'
# 'm bed: 892000.0 g, C bed: 3732128.0 J/C'
# 'q:-26954257.777777787 J, -7.487293827160497 kWh'
# 7.487293827160498

# %% [markdown]
# $$ \begin{align}
# T_{init} &= 85 \degree F = 29.4 \degree C \\
# T_{final} &= 72 \degree F = 22.2 \degree C \\
# \Delta T &= -7.2 \degree C \\
# V_{bed} &= 892\ L \\
# m_{bed} &= 892\ L \cdot 1000\ mL/L \cdot 1.0\ g/mL = 8.92 \times 10^5 g \\
# c_{water} &= 4.184\ J / g \degree C \\
# C_{bed} &= m_{bed} \cdot c_{water} = 3.732128 \times 10^6 \ J/\degree C \\
# 1\ kWh &= 3.6 \times 10^6\ J \\
# q &= C_{bed} \cdot \Delta T = -2.6954258 \times 10^7 J = -7.48729 kWh \\
# power &= 7.5 kWh \\
# \end{align} $$
#
# I estimate holding the temperature of the waterbed steady at 85 &deg;F for 24 hours will take 7.5 kWh of electrical power.  Assumptions:
# - None of the applied heat will go to keep the bed itself warm, just the water.  This would likely result in an underestimate of the needed power.
# - Heat will not escape faster to the environment because the water is at a higher temperature over the course of the day.  This would likely result in an underestimate of the needed power.
#
# <strong style="color:red">Note:</strong> The book answer is 7.47 kWh. I find the rounding questionable.  I find the specific answer to three significant digits questionable.   will create an errata.  I forgot to list the assumption of the density of water.

# %% [markdown]
# #### Ex 5.15

# %% [markdown]
# It depends on the temperature of the external environment.  If the environment was colder than the temperatures inside the calorimeter, such as 20 &deg; C, then a poorer insulator would result in more heat escaping to the outside, reducing the amount of heat measured.  However, if the environment was warmer than the temperatures inside the calorimeter, such as 30 &deg; C, then a poorer insulator would result in heat flowing into the calorimeter, increasng the amount of heat measured.
#
# If we assume that the starting temperature of the reactants, 22 &deg; C is the temperature of the environment, then a poorer insulator would result in more heat escaping to the outside, reducing the amount of heat measured.

# %% [markdown]
# #### Ex 5.17

# %% [markdown]
# The heat absorbed would appear greater, because taking the heat capacity of the calorimeter itself into account would increase the heat capacity and mass that the measured temperature change was applied to, increasing the measured amount of heat energy transfer.  Another way to look at it is that by taking the calorimeter into account, we would now be accounting for heat that entered the system that had been missed before.

# %% [markdown]
# #### Ex 5.19

# %%
((0.24 * 45 * 25) + (4.184 * 180 * 95)) / ((4.184 * 180) + (0.24 * 45))
# Out:
# 94.01036757775682

# %% [markdown]
# Reaching back to the equation I already munged around for Example 5.3, we have.
# $$ \begin{align}
# T_{final} &=
# \frac{c_b \cdot m_b \cdot T_{b\ initial} + c_a \cdot m_a \cdot T_{a\ initial}}
#      {c_a \cdot m_a + c_b \cdot m_b}
# \end{align} $$
#
# If we call $a$ the coffee and $b$ the spoon, then...
# $$ \begin{align}
# T_{a,init} &= 95 \degree C \\
# T_{b,init} &= 25 \degree C \\
# c_a &= 4.184\ J/g \degree C \text{ assumed same as water} \\
# c_b &= 0.24\ J/g \degree C \\
# m_a &= 180\ g \\
# m_b &= 45\ g \\
# T_{final} &= 94 \degree C \\
# \end{align} $$
#
# So the coffee temperature dropped by 1 &deg; C.

# %% [markdown]
# #### Ex 5.21
# The temperature of the cooling water as it leaves the hot engine of an automobile is 240 °F. After it passes through the radiator it has a temperature of 175 °F. Calculate the amount of heat transferred from the engine to the surroundings by one gallon of water with a specific heat of 4.184 J/g °C.

# %%
tiC = (240 - 32) * 5 / 9
tfC = (175 - 32) * 5 / 9
dt = tfC - tiC
display(f'T init: {tiC} C, T fin: {tfC} C, delta T: {dt}')
quarts_per_gallon = 4
quarts_per_liter = 1.057
liters_per_quart = 0.9463
ml_per_liter = 1000
g_per_ml = 1.0
vwg = 1
vwl = 1 * quarts_per_gallon / quarts_per_liter
vwl2 = 1 * quarts_per_gallon * liters_per_quart
vwml = vwl * ml_per_liter
vwml2 = vwl2 * ml_per_liter
display(f'Vol water: {vwg} gal, {vwl} or {vwl2} L, {vwml2} mL')
mwg = vwml * g_per_ml
mwg2 = vwml2 * g_per_ml
display(f'Mass water: {mwg} g or {mwg2} g')
q = mwg * 4.184 * dt
q2 = mwg2 * 4.184 * dt
display(f'q: {q} J or {q2} J')
display(f'Heat transferred to surroundings = {-round(q2 / 1000, 0)} kJ')
# Out:
# 'T init: 115.55555555555556 C, T fin: 79.44444444444444 C, delta T: -36.111111111111114'
# 'Vol water: 1 gal, 3.784295175023652 or 3.7852 L, 3785.2000000000003 mL'
# 'Mass water: 3784.295175023652 g or 3785.2000000000003 g'
# 'q: -571764.9532219069 J or -571901.6622222223 J'
# 'Heat transferred to surroundings = 572.0 kJ'

# %% [markdown]
# **Note:** Book rounded it to 5.7 x 10<sup>2</sup> kJ.

# %% [markdown]
# #### Ex 5.23
# If a reaction produces 1.506 kJ of heat, which is trapped in 30.0 g of water initially at 26.5 °C in a calorimeter like that in Figure 5.12, what is the resulting temperature of the water?

# %%
tf = 1.506 * 1000 / (30.0 * 4.184) + 26.5
tf
# Out:
# 38.4980879541109

# %% [markdown]
# $$ \begin{align}
# q &= mc \Delta T = mc(T_{final} - T_{init}) \\[1ex]
# \Delta T &= \frac{q}{mc} \\[1ex]
# T_{final} - T_{init} &= \frac{q}{mc} \\[1ex]
# T_{final} &= \frac{q}{mc} + T_{init} \\[1ex]
# T_{final} &= 38.5 \degree C \\[1ex]
# \end{align} $$

# %% [markdown]
# #### Ex 5.25
# Dissolving 3.0 g of CaCl<sub>2</sub>(s) in 150.0 g of water in a calorimeter (Figure 5.12) at 22.4 °C causes the temperature to rise to 25.8 °C. What is the approximate amount of heat involved in the dissolution, assuming the specific heat of the resulting solution is 4.18 J/g °C? Is the reaction exothermic or endothermic?

# %%
display((150.0 + 3.0) * 4.18 * (25.8 - 22.4))
display((150.0) * 4.18 * (25.8 - 22.4))
# Out:
# 2174.436000000001
# 2131.8000000000015

# %% [markdown]
# The amount of heat involved is approximately 2.17 kJ.  The reaction is exothermic.
#
# **Note:** The book gave -2.2 kJ and exothermic.

# %% [markdown]
# #### Ex 5.27

# %%
(100 + 3.15 + 1.52) * 4.20 * 3.1
# Out:
# 1362.8034000000002

# %% [markdown]
# Approximately 1.4 kJ of heat were absorbed.

# %% [markdown]
# #### Ex 5.29
#
# If the 3.21 g of NH<sub>4</sub>NO<sub>3</sub> in Example 5.6 were dissolved in 100.0 g of water under the same conditions, how much would the temperature change? Explain your answer.  In Example 5.6, it is dissolved in 50.0 g of water instead and the temperature drops from 24.9&deg;C to 20.3&deg;C, a drop of 4.6&deg;C, absorbing 1.0 kJ of energy.

# %%
display(24.9 - 20.3)
q_example_5_6 = -((3.21 + 50.0) * 4.184 * (20.3 - 24.9))
q_rounded_5_6 = 1000
q_book_intermediate_5_6 = 4.184 * 53.2 * -4.6
display(f'q from 5.6: {q_example_5_6}, rounded: {q_rounded_5_6}')
dt = q_example_5_6 / ((100.0 + 3.21) * 4.184)
dt_from_rounded = q_rounded_5_6 / ((100.0 + 3.21) * 4.184)
dt_from_intermediate = q_book_intermediate_5_6 / ((100.0 + 3.21) * 4.184)
display(f'dT: {dt}, from round: {dt_from_rounded}, from inter: {dt_from_intermediate}')
display(f'T final: {24.9 - dt}, T final from round: {24.9 - dt_from_rounded}')
display(f'Short T final 1: {24.9 - ((24.9 - 20.3) / 2)}')
display(f'Short T final 2: {24.9 - (1.0 * 1000 / ((100.0 + 3.21) * 4.184))}')
display(f'Short q: {-(50.0 + 3.21) * 4.184 * (20.3 - 24.9)}')
display(f'Short T final 3: {24.9 - (1024.1 / ((100.0 + 3.21) * 4.184))}')
# Out:
# 4.599999999999998
# 'q from 5.6: 1024.1009439999996, rounded: 1000'
# 'dT: 2.3715337661079343, from round: 2.3157226638665565, from inter: -2.371088072861157'
# 'T final: 22.528466233892065, T final from round: 22.584277336133443'
# 'Short T final 1: 22.6'
# 'Short T final 2: 22.584277336133443'
# 'Short q: 1024.1009439999996'
# 'Short T final 3: 22.528468419934256'

# %% [markdown]
# Assuming:
# - Solution specific heat that of water (like example 5.6 assumed)
# - No heat transferred with environment
# - NH<sub>4</sub>NO<sub>3</sub> was the limiting reactant so that energy absorbed is same
# Then...
# $$ \begin{align}
# q_{rx} &= -q_{sol} = -mc \Delta T \\[1ex]
# \Delta T &= \frac{q_{sol}}{mc} \\
#     &= \frac{1000\ J}{(100.0\ g + 3.21\ g) \cdot 4.184\ J/g \degree C} \\[1ex]
#     &= 2.3\ \degree C \\
#     &\  \mathbf{or} \\
#     &= \frac{1024.1009439999996\ J}{(100.0\ g + 3.21\ g) \cdot 4.184\ J/g \degree C} \\[1ex]
#     &= 2.4\ \degree C \\
# \end{align} $$
# In other words, I worked backwards from the heat absorbed and essentially used the heat capacity of the combined increased solvent and unchanged solute to calculate a new temperature change.  The result makes sense.  The majority of the mass was in the water, so doubling the water should approximately halve the temperature change.
#
# <strong style="color:red">Note:</strong> The book answer was 22.6.  I made 3 errata.

# %% [markdown]
# #### Ex 3.31
# When a 0.740-g sample of trinitrotoluene (TNT), $\ce{C7H5N2O6}$, is burned in a bomb calorimeter, the temperature increases from 23.4 °C to 26.9 °C. The heat capacity of the calorimeter is 534 J/°C, and it contains 675 mL of water. How much heat was produced by the combustion of the TNT sample?

# %%
C_sur = 534 + 675 * 1.0 * 4.184
q_rx = C_sur * (26.9 - 23.4)
display(f'C surrounding: {C_sur}, q rx: {q_rx}')
C_total = 534 + (675 + .740) * 4.184
q_total = C_total * (26.9 - 23.4)
display(f'q including bad approximation of c of TNT itself: {q_total}')
display('Ok, now try to explain the book answer with intermediate rounding.')
C_water = 675 * 4.184
C_water_r = round(C_water, -1)
C_all = C_water_r + 534
C_all_r = round(C_all, -1)
display(f'C water: {C_water} rounds to {C_water_r}, C all: {C_all} rounds to {C_all_r}')
dt = 26.9 - 23.4
display(f'Delta t: {dt}')
q_all = C_all_r * dt
q_all_r = round(q_all, -2)
display(f'q all: {q_all} rounds to {q_all_r}')
display(f'one step: {(534 + (675 * 1.0 * 4.184)) * (26.9 - 23.4)}')
# Out:
# 'C surrounding: 3358.2000000000003, q rx: 11753.7'
# 'q including bad approximation of c of TNT itself: 11764.53656'
# 'Ok, now try to explain the book answer with intermediate rounding.'
# 'C water: 2824.2000000000003 rounds to 2820.0, C all: 3354.0 rounds to 3350.0'
# 'Delta t: 3.5'
# 'q all: 11725.0 rounds to 11700.0'
# 'one step: 11753.7'

# %% [markdown]
# $$ \begin{align}
# C_{surroundings} &= C_{calorimeter} + C_{water} \\
#     &= 534\ J/\degree C + 675\ mL \cdot 1.0\ g/mL \cdot 4.184\ J/g \degree C \\
#     &= 3358.2\ J/\degree C \\
# q_{rx} &= -q_{surroundings} = -C_{surroundings} * \Delta T \\
#     &= -3358.2\ J/\degree C \cdot (26.9 - 23.4 \degree C) \\
#     &= -11.8\ kJ
# \end{align} $$
# So 11.8 kJ of heat was produced, or 12 kJ if you want to round based on the significant figures in the 1.0 g/mL approximation for the density of water.
#
# <strong style="color:red">Note:</strong> The book answer, 11.7 kJ, appears to have used intermediate rounding, possibly without even guard digits.  I added an errata.

# %% [markdown]
# #### Ex 5.33
# The amount of fat recommended for someone with a daily diet of 2000 Calories is 65 g. What percent of the calories in this diet would be supplied by this amount of fat if the average number of Calories for fat is
# 9.1 Calories/g?

# %%
(65 * 9.1) / 2000 * 100
# Out:
# 29.575000000000003

# %% [markdown]
# Looks like 30%.

# %% [markdown]
# #### Ex 5.35
# What is the maximum mass of carbohydrate in a 6-oz serving of diet soda that contains less than 1 Calorie per can if the average number of Calories for carbohydrates is 4.1 Calories/g?

# %%
1 / 4.1
# Out:
# 0.24390243902439027

# %% [markdown]
# Less than .24 g (or .2 g if 1 Calorie significant figures is used.)

# %% [markdown]
# #### Ex 5.37
# A serving of a breakfast cereal contains 3 g of protein, 18 g of carbohydrates, and 6 g of fat. What is the Calorie content of a serving of this cereal if the average number of Calories for fat is 9.1 Calories/g, for carbohydrates is 4.1 Calories/g, and for protein is 4.1 Calories/g?

# %%
3 * 4.1 + 18 * 4.1 + 6 * 9.1
# Out:
# 140.7

# %% [markdown]
# 140 Calories.

# %% [markdown]
# #### Ex 5.39
# Explain how the heat measured in Example 5.5 differs from the enthalpy change for the exothermic reaction described by the following equation:
#
# $$\ce{HCl⁡(aq) + NaOH⁡(aq) -> NaCl⁡(aq) + H2O(l)}$$
#
# (Note that the chemical formula is identical to the Example 5.5 coffee cup calorimeter example, including the (aq) and (l) states of matter.)
#
# My answer:
#
# Numerically they would only differ in that the enthalpy would include any heat lost to the environment, including any heat lost to the coffee cup calorimeter itself.  In other words, the definition enthalpy change does not make use of the measuring assumptions used in Example 5.5.  Other than that, they would be numerically identical.
#
# Where they differ is in the meaning.  The enthalpy change only equals the heat quantity under the assumption of constant pressure so that the work term of the enthalpy definition is cancelled out by the P times &Delta;V work done by or on the system when it is under constant pressure but not constant volume.
#
# <strong style="color:blue">Oops.</strong> The book answer is:
# > The enthalpy change of the indicated reaction is for exactly 1 mol HCL and 1 mol NaOH; the heat in the example is produced by 0.0500 mol HCl and 0.0500 mol NaOH.
#
# From book Ch 5.3:
# > This &Delta;H value indicates the amount of heat associated with the reaction involving the number of moles of reactants and products as shown in the chemical equation.
#
# That Ch 5.3 book quote was from the section on $\Delta H$, before any of the sections on $\Delta H \degree$, $\Delta H \rlap \degree _c$, or $\Delta H \rlap \degree _f$.

# %% [markdown]
# #### Ex 5.41
# Calculate the enthalpy of solution (ΔH for the dissolution) per mole of $\ce{NH4NO3}$ under the conditions described in Example 5.6.

# %%
def ex5_41(s):
    with localcontext(prec = 7):
        amu_n = s.N + s.H*4 + s.N + s.O*3
        q_samp = - (50.0 + 3.21) * 4.184 * (20.3 - 24.9)
        q_samp_r = 1000.0
        q_mol = Decimal(q_samp) * amu_n / Decimal(3.21)
        q_mol_r = Decimal(q_samp_r) * amu_n / Decimal(3.21)
        return {
            'amu N': s.N,
            'amu H': s.H,
            'amu O': s.O,
            'amu NH4NO3': amu_n,
            'q 3.21 g': q_samp,
            'q mol': q_mol,
            'q mol one step': 1024.1 * (14.01 + 1.008 * 4 + 14.01 + 16.00 * 3) / 3.21,
            'q mol r': q_mol_r,
        }
compares(ex5_41)
# Out:
#                                 b                  i                  n  \
# amu N                       14.01             14.007             14.007
# amu H                       1.008             1.0080             1.0080
# amu O                       16.00             15.999             15.999
# amu NH4NO3                 80.052            80.0430            80.0430
# q 3.21 g       1024.1009439999996 1024.1009439999996 1024.1009439999996
# q mol                    25539.36           25536.48           25536.48
# q mol one step  25539.33121495327  25539.33121495327  25539.33121495327
# q mol r                  24938.32           24935.51           24935.51
#
#                                 c
# amu N                      14.007
# amu H                       1.008
# amu O                      15.999
# amu NH4NO3                 80.043
# q 3.21 g       1024.1009439999996
# q mol                    25536.48
# q mol one step  25539.33121495327
# q mol r                  24935.51

# %% [markdown]
# $$\Delta H = 25.5\ kJ$$
# <strong style="color:red">Note:</strong> Book answer is 25 kJ mol<sup>-1</sup>.

# %% [markdown]
# #### Ex 5.43
# Calculate the enthalpy of solution (ΔH for the dissolution) per mole of $\ce{CaCl2}$ (refer to Exercise 5.25).

# %%
def ex4_43(s):
    with localcontext(prec = 7):
        amu_c = s.Ca + s.Cl*2
        q_30 = - (150.0 + 3.0) * 4.18 * (25.8 - 22.4)
        q_30_r = -2200
        d_h = Decimal(q_30) * amu_c / Decimal(3.0)
        d_h_r = Decimal(q_30_r) * amu_c / Decimal(3.0)
        return {
            'amu CaCl2': amu_c,
            'q for 3.0 g': q_30,
            'Delta H': d_h,
            'Delta H r': d_h_r,
        }
compares(ex4_43)
# Out:
#                              b                  i                  n  \
# amu CaCl2               110.98            110.978             110.98
# q for 3.0 g -2174.436000000001 -2174.436000000001 -2174.436000000001
# Delta H              -80439.63           -80438.2          -80439.63
# Delta H r            -81385.33          -81383.87          -81385.33
#
#                              c
# amu CaCl2              110.978
# q for 3.0 g -2174.436000000001
# Delta H               -80438.2
# Delta H r            -81383.87

# %% [markdown]
# Most accurate answer from unrounded answer for Exercise 5.25:
# $$ \Delta H [\ce{CaCl2}] = -80\ kJ/mol $$
# Likely book answer started from rounded answer for Exercise 5.25:
# $$ \Delta H [\ce{CaCl2}] = -81\ kJ/mol $$
# <strong style="color:red">Note:</strong> The book answer of 81 kJ mol<sup>-1</sup> seems to have the wrong sign.  At least I think it should be negative like the book answer for Exercise 5.25.  I put in an errata.

# %% [markdown]
# #### Ex 5.45
# How much heat is produced by burning 4.00 moles of acetylene under standard state conditions?
#
#
# Looking up the standard heat of combustion $Delta H \rlap \degree c$ for Acetylene in Table 5.2 gives $\Delta H \rlap \degree _c [\ce{C2H2(g)}] = -1301.1\ kJ/mol$.

# %%
-1301.1 * -1 * 4.00
# Out:
# 5204.4

# %% [markdown]
# $$q_{produced} = 5.20 \times 10^3\ kJ$$
# <strong style="color:red">Note:</strong> Reported errata because book answer of 5204.4 kJ was not properly rounded as far as I can tell.

# %% [markdown]
# #### Ex 5.47
# How many moles of isooctane must be burned to produce 100 kJ of heat under standard state conditions?
#
# Looking up the Standard Molar Enthalpy of Combustion for isooctane in Table 5.2 gives –5465.5 kJ/mol.

# %%
100 / -5465.5 * -1
# Out:
# 0.018296587686396488

# %% [markdown]
# 0.0183 moles of isooctane.

# %% [markdown]
# #### Ex 5.49
# When 2.50 g of methane burns in oxygen, 125 kJ of heat is produced. What is the enthalpy of combustion per mole of methane under these conditions?

# %%
def ex5_49(s):
    with localcontext(prec = 7):
        amu_m = s.C + s.H*4
        d_h = Decimal('-125') * amu_m / Decimal('2.50')
        return {
            'amu CH4': amu_m,
            'Delta H': d_h,
        }
compares(ex5_49)
# Out:
#               b        i        n        c
# amu CH4  16.042  16.0430  16.0430   16.043
# Delta H  -802.1  -802.15  -802.15  -802.15

# %% [markdown]
# $$ \Delta H \rlap \degree _c [\ce{CH4(g)}] = -802\ kJ/mol$$

# %% [markdown]
# #### Ex 5.51
# A sample of 0.562 g of carbon is burned in oxygen in a bomb calorimeter, producing carbon dioxide. Assume both the reactants and products are under standard state conditions, and that the heat released is directly proportional to the enthalpy of combustion of graphite. The temperature of the calorimeter increases from 26.74 °C to 27.93 °C. What is the heat capacity of the calorimeter and its contents?

# %%
def ex5_51(s):
    with localcontext(prec = 7):
        m_c = Decimal('0.562')
        dt = Decimal('27.93') - Decimal('26.74')
        dh_c = Decimal('-393.5') * 1000
        amu_c = s.C
        q_rxn = m_c / amu_c * dh_c
        C_cal = -q_rxn / dt
        return {
            'Delta T': dt,
            'amu C': amu_c,
            'q rxn': q_rxn,
            'C cal': C_cal,
        }
ex5_51(b)
# Out:
# {'Delta T': Decimal('1.19'),
#  'amu C': Decimal('12.01'),
#  'q rxn': Decimal('-18413.57'),
#  'C cal': Decimal('15473.59')}

# %% [markdown]
# $$ \begin{align}
# m_{carbon} &= 0.562 g \\
# \Delta T &= (27.93 - 26.74 \degree C) = 1.19 \degree C \\
# \Delta H \rlap \degree _c [C(s, graphite)] &= -393.5\ kJ/mol \text{ from Table 5.2} \\
# q_{rxn} &= \frac{m_{carbon}}{molar\ mass_{carbon}} \cdot \Delta H \rlap \degree _c \\
# q_{rxn} &= 0.562\ g \cdot \frac{1\ mol}{12.01\ g} \cdot \frac{-393.5\ kJ}{1\ mol} \\
#     &= -18413.57\ J \\
# q_{calorimeter} = -q_{rxn} &= C_{calorimeter} \cdot \Delta T \\
# C_{calorimeter} &= \frac{-q_{rxn}}{\Delta T} \\
#     &= \frac{18413.57\ J}{1.19 \degree C} \\
#     &= 15.5\ kJ/\degree C \\
# \end{align} $$

# %% [markdown]
# #### Ex 5.53
# Homes may be heated by pumping hot water through radiators. What mass of water will provide the same amount of heat when cooled from 95.0 to 35.0 °C, as the heat provided when 100 g of steam is cooled from 110 °C to 100 °C?

# %%
def ex5_53():
    c_l = 4.184
    c_g = 1.864
    return {
        'm l': (100 * c_g * (100 - 110)) / (c_l * (35.0 - 95.0))
    }
ex5_53()
# Out:
# {'m l': 7.425111536010197}

# %% [markdown]
# $$ \begin{align}
# q_{liquid} &= q_{gas} \\
# c_l &= 4.184\ J/g \degree C \\
# c_g &= 1.864\ J/g \degree C \\
# m_l c_l \Delta T_l &= m_g c_g \Delta T_g \\
# m_l &= \frac{m_g c_g \Delta T_g}{c_l \Delta T_l} \\
# m_l &= 7.43\ g \\
# \end{align} $$

# %% [markdown]
# #### Ex 5.55
#
# Does the standard enthalpy of formation of H2O(g) differ from ΔH° for the reaction
# $$\ce{2H2⁢(g) +O2⁡(g)->2⁢H2O(g)}$$
# Yes, it differs.  The standard enthalpy of formation $\Delta H \rlap \degree _f$ for a substance is the enthalpy for creating 1 mole of a pure substance from the most stable forms of the elemental ingredients.  In the formula provided, it looks like the reactants are indeed elemental and in their standard stable states.  However, the formula shows making 2 moles of H2O(g), not 1 mole.  The formula whose $\Delta H \degree$ would equal the standard enthalpy of formation of H2O(g) needs to be halved like this.
# $$\ce{H2⁢(g) + \frac12 O2⁡(g)->⁢H2O(g)}$$
# Book answer is just "Yes."  LOL.

# %% [markdown]
# #### Ex 5.57
# How many kilojoules of heat will be released when exactly 1 mole of manganese, Mn, is burned to form $\ce{Mn3O4(s)}$ at standard state conditions?

# %%
Decimal('-1378.83') / Decimal('3')
# Out:
# Decimal('-459.61')

# %% [markdown]
# Let's see, the formula would be
# $$ \ce{Mn(s) + \frac43 O2(g) -> \frac13 Mn3O4(s)} $$
# Per Appendix G, the standard enthalpy of formation of 1 mole of $\ce{Mn3O4(s)}$ is
# $$ \Delta H \rlap \degree _f = -1378.83\ kJ/mol $$
# Since the requested reaction forms only 1/3 of a mole, we need to divide by 3 like
# $$ \Delta H \degree = \frac{-1378.83\ kJ/mol}{3} = 459.610\ kJ/mol $$
#
# <strong style="color:red">Note:</strong> I originally forgot to change the sign to positive since the question asks for "heat released".  I also hadn't kept the answer to a full 6 significant figures to start with, putting -459.61.  However, the book answer is 459.6 kJ to 4 significant figures.  I raised an errata for that rounding, but noted it might not matter.

# %% [markdown]
# #### Ex 5.59
# The following sequence of reactions occurs in the commercial production of aqueous nitric acid:
#
# Determine the total enthalpy change for the production of one mole of aqueous nitric acid by this process. Coproducts of the net reaction include water and nitrogen monoxide.
#
# $$ \begin{alignat}{2}
# &\ce{4⁢NH3⁢(g) + 5⁢O2⁡(g) -> 4⁢NO⁡(g) + 6⁢H2O(l)} \quad &\Delta H = -907\ kJ \\
# &\ce{2⁢NO⁡(g) + O2⁡(g) -> 2⁢NO2⁢(g)} \quad &\Delta H = -113\ kJ \\
# &\ce{3⁢NO2(g) + H2O(l) -> 2⁢HNO3⁢(aq) + NO⁡(g)} \quad &\Delta H = -139\ kJ \\
# \end{alignat} $$

# %%
display(-907 * 3 / 8)
display(-113 * 3 / 4)
display(-139 / 2)
display((-907 * 3 / 8) + (-113 * 3 / 4) + (-139 / 2))
# Out:
# -340.125
# -84.75
# -69.5
# -494.375

# %% [markdown]
# Let's put those 3 equations in the forms needed to produce 1 mole of $\ce{HNO3(aq)}$.
#
# $$ \begin{alignat}{2}
# &\ce{\frac32 ⁢NH3⁢(g) + \frac{15}8 ⁢O2⁡(g) -> \frac32 ⁢NO⁡(g) + \frac94 ⁢H2O(l)} \quad &&\Delta H = -340.125\ kJ \\[.5ex]
# &\ce{\frac32 ⁢NO⁡(g) + \frac34 O2⁡(g) -> \frac32 ⁢NO2⁢(g)} \quad &&\Delta H = -84.75\ kJ \\[.5ex]
# &\ce{\frac32 ⁢NO2(g) + \frac12 H2O(l) -> HNO3⁢(aq) + \frac12 NO⁡(g)} \quad &&\Delta H = -69.5\ kJ \\[.5ex]
# \hline
# &\ce{\frac32 ⁢NH3⁢(g) + \frac{21}8 ⁢O2⁡(g) -> HNO3⁢(aq) + \frac74 ⁢H2O(l) + \frac12 NO⁡(g)} \quad &&\Delta H = -494.375\ kJ \\[.5ex]
# &\ &&\Delta H = -494\ kJ/mol \\[.5ex]
# \end{alignat} $$
#
# **Note:** I forgot to put per mole on my answer at first until I saw the book answer.

# %% [markdown]
# #### 5.61
# From the molar heats of formation in Appendix G, determine how much heat is required to evaporate one mole of water:
# $$ \ce{H2O(l) -> H2O(g)} $$

# %%
-241.82 - -285.83
# Out:
# 44.00999999999999

# %% [markdown]
# $$ \begin{align}
# \Delta H \rlap \degree _f\ [\ce{H2O(l)}] &= -285.83\ kJ/mol \\[.5ex]
# \Delta H \rlap \degree _f\ [\ce{H2O(g)}] &= -241.82\ kJ/mol \\[.5ex]
# \Delta H \rlap \degree _{rx}
#     &= \sum{n \cdot \Delta H \rlap \degree _f \text{ (products)}} -
#        \sum{n \cdot \Delta H \rlap \degree _f \text{ reactants}} \\[.5ex]
#     &= \Delta H \rlap \degree _f\ [\ce{H2O(g)}] -
#        \Delta H \rlap \degree _f\ [\ce{H2O(l)}] \\[.5ex]
#     &= -241.82 - (-285.83\ kJ/mol) \\[.5ex]
#     &= 44.01\ kJ/mol \\[.5ex]
# \end{align} $$
# So the answer is 44.01 kJ.
#
# The book gives 44.01 kJ/mol, but the question already says "one mole".

# %% [markdown]
# #### Ex 5.63

# %%
-314 + -80
# Out:
# -394

# %% [markdown]
# Answer is -394 kJ.  This time the book did not add /mol.

# %% [markdown]
# #### Ex 5.65

# %%
-( -224 + -41.2)
# Out:
# 265.2

# %% [markdown]
# Answer is +265 kJ.

# %% [markdown]
# #### Ex 5.67

# %%
display((66.4 + (-(-114.1))) / 2)
display((66.4 / 2) + (-(-114.1 / 2)))
display((66.4 + 114.1) / 2)
# Out:
# 90.25
# 90.25
# 90.25

# %% [markdown]
# Answer is +90.2 kJ/mol.
#
# <strong style="color:red">Note:</strong> The book answer is 90.3 kJ/mol, but by the rounding rules in Ch 1.5 I believe it should round to 90.2 kJ/mol.  I added an errata.

# %% [markdown]
# #### Ex 5.69
# Using the data in Appendix G, calculate the standard enthalpy change for each of the following reactions:
# $$ \begin{alignat}{2}
# &(a)\ &&\ce{Si⁡(s) + 2⁢F2⁡(g) -> SiF4⁢(g)} \\
# &(b) &&\ce{2C(s) + 2⁢H2⁡(g) + O2⁡(g) -> CH3⁢CO2H(l)} \\
# &(c) &&\ce{CH4⁢(g) + N2⁡(g) -> HCN⁡(g) + NH3⁢(g)} \\
# &(d) &&\ce{CS2⁢(g) + 3⁢Cl2⁢(g) -> CCl4⁢(g) + S2⁢Cl2⁢(g)} \\
# \end{alignat} $$

# %%
dhf_SiF4g = -1615.0
dhf_CH3CO2Hl = -484.3
dhf_CH4g = -74.6
dhf_HCNg = 135.5
dhf_NH3g = -45.9
dhf_CS2g = 116.9
dhf_CCl4g = -95.7
dhf_S2Cl2g = -19.50
display(dhf_SiF4g)
display(dhf_CH3CO2Hl)
display((dhf_HCNg + dhf_NH3g) - (dhf_CH4g))
display((dhf_CCl4g + dhf_S2Cl2g) - (dhf_CS2g))
# Out:
# -1615.0
# -484.3
# 164.2
# -232.10000000000002

# %% [markdown]
# $$ \begin{alignat}{3}
# &(a)\ &&\ce{Si⁡(s) + 2⁢F2⁡(g) -> SiF4⁢(g)} \quad
#     &&\Delta H \degree = -1615.0\ kJ \\
# &(b) &&\ce{2C(s) + 2⁢H2⁡(g) + O2⁡(g) -> CH3⁢CO2H(l)} \quad
#     &&\Delta H \degree = -484.3\ kJ \\
# &(c) &&\ce{CH4⁢(g) + N2⁡(g) -> HCN⁡(g) + NH3⁢(g)} \quad
#     &&\Delta H \degree = 164.2\ kJ \\
# &(d) &&\ce{CS2⁢(g) + 3⁢Cl2⁢(g) -> CCl4⁢(g) + S2⁢Cl2⁢(g)} \quad
#     &&\Delta H \degree = -232.1\ kJ \\
# \end{alignat} $$
#
# <strong style="color:red">Note:</strong> The book had /mol on the first two answers, as follows, which seems odd, so I mentioned it in an errata.
#
# (a) −1615.0 kJ mol<sup>−1</sup>; (b) −484.3 kJ mol<sup>−1</sup>; (c) 164.2 kJ; (d) −232.1 kJ

# %% [markdown]
# #### Ex 5.71
# The decomposition of hydrogen peroxide, $\ce{H2O2}$, has been used to provide thrust in the control jets of various space vehicles. Using the data in Appendix G, determine how much heat is produced by the decomposition of exactly 1 mole of $\ce{H2O2}$ under standard conditions.
# $$ \ce{2⁢H2⁢O2⁡(l) -> 2⁢H2O(g) + O2⁡(g)} $$

# %%
dhf_H2O2l = -187.78
dhf_H2Og = -241.82
display(dhf_H2Og - dhf_H2O2l)
# Out:
# -54.03999999999999

# %% [markdown]
# The answer is 54.04 kJ (or 54.04 kJ/mol, however the book decides to express it this time.)
#
# <strong style="color:red">Note:</strong> The book reverses the sign, giving the answer as -54.04 kJ mol<sup>-1</sup>.  I think the sign should be positive given the way the question is asked, and will add an errata questioning it.

# %% [markdown]
# #### Ex 5.73
# Calculate the enthalpy of combustion of butane, $\ce{C4H10(g)}$ for the formation of $\ce{H2O(g)}$ and $\ce{CO2(g)}$. The enthalpy of formation of butane is −126 kJ/mol.
#
# I'm not sure the exact chemical reaction formula matters, but I think it might, so let's work it out first.
#
# $$ \ce{C4H10(g) + \frac{13}2 O2(g) -> 5 H2O(g) + 4 CO2(g)} $$
# $$ \ce{2 C4H10(g) + 13 O2(g) -> 10 H2O(g) + 8 CO2(g)} $$

# %%
dhf_C4H10g = -126
dhf_CO2g = -393.51
display(dhf_H2Og)
display((5 * dhf_H2Og + 4 * dhf_CO2g) - (dhf_C4H10g))
# Out:
# -241.82
# -2657.14

# %% [markdown]
# Lets use the first formula because it has exactly 1 mole of butane.  I get an answer.
# $$ \Delta H \rlap \degree _c [\ce{C4H10(g)}] = -2657\ kJ/mol$$
#
# <strong style="color:red">Note:</strong> The book appears to have used different rounding, giving an answer of -2660 kJ mol<sup>-1</sup>.

# %% [markdown]
# #### Ex 5.75
# The white pigment TiO2 is prepared by the reaction of titanium tetrachloride, TiCl4, with water vapor in the gas phase:
#
# $$ \ce{TiCl4⁢(g) + 2⁢H2O(g) -> TiO2⁢(s) + 4⁢HCl⁡(g)} $$
#
# How much heat is evolved in the production of exactly 1 mole of TiO2(s) under standard state conditions?

# %%
dhf_TiCl4g = -763.2
dhf_TiO2s = -944.0
dhf_HClg = -92.307
display(dhf_H2Og)
display((dhf_TiO2s + 4*dhf_HClg) - (dhf_TiCl4g + 2*dhf_H2Og))
# Out:
# -241.82
# -66.38799999999992

# %% [markdown]
# $$ \Delta H \degree = -66.4\ kJ/mol $$

# %% [markdown]
# #### Ex 5.77
# In the early days of automobiles, illumination at night was provided by burning acetylene, C2H2. Though no longer used as auto headlamps, acetylene is still used as a source of light by some cave explorers. The acetylene is (was) prepared in the lamp by the reaction of water with calcium carbide, CaC2:
# $$ \ce{CaC2⁢(s) + 2⁢H2O(l) -> Ca⁢(OH)2⁢(s) + C2⁢H2⁡(g)} $$
# Calculate the standard enthalpy of the reaction. The Δ𝐻°f of CaC2 is −15.14 kcal/mol.

# %%
dhf_CaC2s = -15.14 * 4.184 # Times 4.184 to convert kcal to kJ.
dhf_C2H2g = 227.4
dhf_H2Ol = -285.83
dhf_Ca_OH_2s = -985.2
display(dhf_CaC2s)
display((dhf_Ca_OH_2s + dhf_C2H2g) - (dhf_CaC2s + 2*dhf_H2Ol))
# Out:
# -63.345760000000006
# -122.79424000000006

# %% [markdown]
# $$ \Delta H \degree = -122.8\ kJ/mol $$
# Or, if the book giving the Δ𝐻°f of CaC2 as −15.14 kcal/mol was a mistake, and they meant -15.14 kJ/mol, then...

# %%
dhf_CaC2s = -15.14
display((dhf_Ca_OH_2s + dhf_C2H2g) - (dhf_CaC2s + 2*dhf_H2Ol))
# Out:
# -171.0000000000001

# %% [markdown]
# $$ \Delta H \degree = -171.0\ kJ/mol $$

# %% [markdown]
# **Note:** The book answer is -122.8 kJ.  **Holy moly** that is tricky.  Giving the standard enthalpy of formation in kcal/mol not kJ/mol.  Their value looks correct though, according to the [Wikipedia article on Calcium Carbide](https://en.wikipedia.org/wiki/Calcium_carbide), the standard enthalpy of formation is -63 kJ/mol, which is what I got multiplying their -15.14 times 4.184 to convert Joules to moles.  In other words, the book is right, but very tricky.

# %% [markdown]
# #### Ex 7.79
# The enthalpy of combustion of hard coal averages −35 kJ/g, that of gasoline, 1.28 × 10<sup>5</sup> kJ/gal. How many kilograms of hard coal provide the same amount of heat as is available from 1.0 gallon of gasoline? Assume that the density of gasoline is 0.692 g/mL (the same as the density of isooctane).
#
# First, why is the enthalpy of combustion of gasoline a positive number.  Shouldn't be negative?  The enthalpy of combustion for isooctane per mole is -5465.5 kJ according to Table 5.2.  Let's see if their value checks out from isooctane if the sign is reversed.

# %%
quarts_per_gallon = 4
liters_per_quart = 0.9463
ml_per_liter = 1000
g_per_ml_gasoline = 0.692
ml_per_gallon = quarts_per_gallon * liters_per_quart * ml_per_liter
g_per_gallon = g_per_ml_gasoline * ml_per_gallon
amu_isooctane = b.C*8 + b.H*18
mol_per_gallon = g_per_gallon / float(amu_isooctane)
mol_per_gallon
dhc_isooctane = -5465.5
kJ_per_gallon = dhc_isooctane * mol_per_gallon
kJ_per_gallon
# Out:
# -125333.58431853201

# %% [markdown]
# Ok, so using some values from isooctane instead, I got -1.25 x 10<sup>5</sup> kJ/gal, which is close to their 1.28 x 10<sup>5</sup> kJ/gal, but with the sign reversed.
#
# Ok, on to the actual problem.

# %%
dhc_gasoline_per_gallon = -1.28 * 10**5
dhc_coal_per_kg = -35 * 10**3
dhc_gasoline_per_gallon / dhc_coal_per_kg
# Out:
# 3.657142857142857

# %% [markdown]
# So I get an ansewr of 3.7 kg of hard coal, matching the book, but...
#
# <strong style="color:red">Note:</strong> The book question used the wrong sign for the enthalpy of combustion of gasoline.  I will report an errata.

# %% [markdown]
# #### Ex 5.81
# Among the substances that react with oxygen and that have been considered as potential rocket fuels are diborane [B2H6, produces B2O3(s) and H2O(g)], methane [CH4, produces CO2(g) and H2O(g)], and hydrazine [N2H4, produces N2(g) and H2O(g)]. On the basis of the heat released by 1.00 g of each substance in its reaction with oxygen, which of these compounds offers the best possibility as a rocket fuel? The Δ𝐻°
# f of B2H6(g), CH4(g), and N2H4(l) may be found in Appendix G.

# %%
def ex5_81(s):
    with localcontext(prec=8):
        dhf_B2H6g = Decimal('36.4')
        dhf_B2O3s = Decimal('-1273.5')
        dhf_H2Og = Decimal('-241.82')
        dhf_CH4g = Decimal('-74.6')
        dhf_CO2g = Decimal('-393.51')
        dhf_N2H4g = Decimal('95.4')
        dhf_N2H4l = Decimal('50.63')
        dh_B2H6g = (dhf_B2O3s + 3*dhf_H2Og) - (dhf_B2H6g)
        dh_CH4g = (dhf_CO2g + 2*dhf_H2Og) - (dhf_CH4g)
        dh_N2H4g = (2*dhf_H2Og) - (dhf_N2H4g)
        dh_N2H4l = (2*dhf_H2Og) - (dhf_N2H4l)
        amu_B2H6 = s.B*2 + s.H*6
        amu_CH4 = s.C + s.H*4
        amu_N2H4 = s.N*2 + s.H*4
        # For 1 gram of each.
        dh_B2H6g_g = dh_B2H6g / amu_B2H6
        dh_CH4g_g = dh_CH4g / amu_CH4
        dh_N2H4g_g = dh_N2H4g / amu_N2H4
        dh_N2H4l_g = dh_N2H4l / amu_N2H4
        return {
            'dh B2H6g': dh_B2H6g,
            'dh CH4g': dh_CH4g,
            'dh N2H4g': dh_N2H4g,
            'dh N2H4l': dh_N2H4l,
            'amu B2H6': amu_B2H6,
            'amu CH4': amu_CH4,
            'amu N2H4':amu_N2H4,
            'dh 1g B2H6g': dh_B2H6g_g,
            'dh 1g CH4g': dh_CH4g_g,
            'dh 1g N2H4g': dh_N2H4g_g,
            'dh 1g N2H4l': dh_N2H4l_g,
        }
compares(ex5_81)
# Out:
#                       b           i           n           c
# dh B2H6g       -2035.36    -2035.36    -2035.36    -2035.36
# dh CH4g         -802.55     -802.55     -802.55     -802.55
# dh N2H4g        -579.04     -579.04     -579.04     -579.04
# dh N2H4l        -534.27     -534.27     -534.27     -534.27
# amu B2H6         27.668     27.6680     27.6680      27.668
# amu CH4          16.042     16.0430     16.0430      16.043
# amu N2H4         32.052     32.0460     32.0460      32.046
# dh 1g B2H6g  -73.563684  -73.563684  -73.563684  -73.563684
# dh 1g CH4g   -50.028051  -50.024933  -50.024933  -50.024933
# dh 1g N2H4g  -18.065643  -18.069026  -18.069026  -18.069026
# dh 1g N2H4l  -16.668851  -16.671972  -16.671972  -16.671972

# %% [markdown]
# $$ \begin{align}
# \Delta H \rlap \degree _f\ [\ce{B2H6(g)}] &= 36.4 \\[.5ex]
# \Delta H \rlap \degree _f\ [\ce{B2O3(s)}] &= -1273.5 \\[.5ex]
# \Delta H \rlap \degree _f\ [\ce{H2O(g)}] &= -241.82 \\[.5ex]
# \Delta H \rlap \degree _f\ [\ce{CH4(g)}] &= -74.6 \\[.5ex]
# \Delta H \rlap \degree _f\ [\ce{CO2(g)}] &= -393.51 \\[.5ex]
# \Delta H \rlap \degree _f\ [\ce{N2H4(g)}] &= 95.4 \\[.5ex]
# \Delta H \rlap \degree _f\ [\ce{N2H4(l)}] &= 50.63 \\[.5ex]
# \end{align} $$
# $$ \begin{alignat}{2}
# &\ce{B2H6(g) + 3O2(g) -> B2O3(s) + 3H2O(g)} \quad
#     &&\Delta H \degree = -2035.36\ kJ \\[.5ex]
# &\ce{CH4(g) + 2O2(g) -> CO2(g) + 2H2O(g)} \quad
#     &&\Delta H \degree = -802.55\ kJ \\[.5ex]
# &\ce{N2H4(g) + O2(g) -> N2(g) + 2H2O(g)} \quad
#     &&\Delta H \degree = -579.04\ kJ \\[.5ex]
# &\ce{N2H4(l) + O2(g) -> N2(g) + 2H2O(g)} \quad
#     &&\Delta H \degree = -534.27\ kJ \\[.5ex]
# \end{alignat} $$
# $$ \begin{align}
# q\ [1g\ \text{substance}]
#     &= \frac{\Delta H \degree}{\text{molar\ mass}} \\[.5ex]
# q\ [1g\ \ce{B2H6(g)}] &= -73.56368\ kJ/g \\[.5ex]
# q\ [1g\ \ce{CH4(g)}] &= -50.02805\ kJ/g \\[.5ex]
# q\ [1g\ \ce{N2H4(g)}] &= -18.06564\ kJ/g \\[.5ex]
# q\ [1g\ \ce{N2H4(l)}] &= -16.668851\ kJ/g \\[.5ex]
# \end{align} $$
# With just these data in hand, it appears that diborane, $\ce{B2H6}$, would make the best rocket fuel.
#
# <strong style="color:red">Note:</strong>I added an errata suggesting they give the states of matter (e.g. (g)) for the reactants in the question.  This would avoid the confusion of two entries for hydrazine in the Appendix G table, one for liquid, and one for gas.

# %% [markdown]
# #### Ex 5.83
# Ethylene, C2H4, a byproduct from the fractional distillation of petroleum, is fourth among the 50 chemical compounds produced commercially in the largest quantities. About 80% of synthetic ethanol is manufactured from ethylene by its reaction with water in the presence of a suitable catalyst. C2⁢H4⁡(𝑔)+H2O(𝑔)⟶C2⁢H5⁢OH⁡(𝑙)
#
# Using the data in the table in Appendix G, calculate ΔH° for the reaction.

# %%
dhf_H2Og = -241.82
dhf_C2H4g = 52.4
dhf_C2H5OHl = -277.6
(dhf_C2H5OHl) - (dhf_C2H4g + dhf_H2Og)
# Out:
# -88.18000000000004

# %% [markdown]
# $$ \Delta H \degree = -88.2\ kJ/mol $$

# %% [markdown]
# #### Ex 5.85
# Propane, C3H8, is a hydrocarbon that is commonly used as a fuel.
#
# (a) Write a balanced equation for the complete combustion of propane gas.
#
# (b) Calculate the volume of air at 25 °C and 1.00 atmosphere that is needed to completely combust 25.0 grams of propane. Assume that air is 21.0 percent O2 by volume. (Hint: We will see how to do this calculation in a later chapter on gases—for now use the information that 1.00 L of air at 25 °C and 1.00 atm contains 0.275 g of O2.)
#
# (c) The heat of combustion of propane is −2,219.2 kJ/mol. Calculate the heat of formation, Δ𝐻°
# f of propane given that Δ𝐻°
# f of H2O(l) = −285.8 kJ/mol and Δ𝐻°
# f of CO2(g) = −393.5 kJ/mol.
#
# (d) Assuming that all of the heat released in burning 25.0 grams of propane is transferred to 4.00 kilograms of water, calculate the increase in temperature of the water.

# %%
def ex5_85(s):
    with localcontext(prec=8):
        amu_C3H8 = s.C*3 + s.H*8
        amu_O2 = s.O*2
        mol_C3H8 = Decimal('25.0') / amu_C3H8
        mol_O2 = 5 * mol_C3H8
        g_O2 = mol_O2 * amu_O2
        l_air = g_O2 / Decimal('0.275')
        dhc_C3H8 = Decimal('-2219.2')
        dhf_H2Ol = Decimal('-285.8')
        dhf_CO2g = Decimal('-393.5')
        dhf_C3H8g = 3*dhf_CO2g + 4*dhf_H2Ol - dhc_C3H8
        q_C3H8 = dhc_C3H8 * mol_C3H8
        c_H2Ol = Decimal('4.184')
        dt_water = (-q_C3H8 * 10**3) / (Decimal('4.00') * 10**3 * c_H2Ol)
        mol_C3H8_step1 = 25.0 / (3*12.01 + 8*1.008)
        dt_step2 = (-(-2219.2) * 1000 * 0.56697) / (4000 * 4.184)
        return {
            'C3H8 amu': amu_C3H8,
            'O2 amu': amu_O2,
            'mol C3H8 in 25g': mol_C3H8,
            'mol O2 needed': mol_O2,
            'g O2 needed': g_O2,
            'L air needed': l_air,
            'Delta H f C3H8': dhf_C3H8g,
            'q combust 25g C3H8': q_C3H8,
            'dt 4kg water': dt_water,
            'step 1: mol C3H8 in 25g': mol_C3H8_step1,
            'dt 4kg water 2 step': dt_step2,
        }
compares(ex5_85)
# Out:
#                                          b                  i  \
# C3H8 amu                            44.094            44.0970
# O2 amu                               32.00             31.998
# mol C3H8 in 25g                 0.56697056         0.56693199
# mol O2 needed                    2.8348528          2.8346600
# g O2 needed                      90.715290          90.703451
# L air needed                     329.87378          329.83073
# Delta H f C3H8                      -104.5             -104.5
# q combust 25g C3H8              -1258.2211         -1258.1355
# dt 4kg water                     75.180515          75.175400
# step 1: mol C3H8 in 25g 0.5669705628883748 0.5669705628883748
# dt 4kg water 2 step      75.18043881453156  75.18043881453156
#
#                                          n                  c
# C3H8 amu                           44.0970             44.097
# O2 amu                              31.998             31.998
# ...

# %% [markdown]
# Ex 5.85(a):
# $$ \ce{C3H8(g) + 5O2(g) -> 3CO2(g) + 4H2O(l)} $$
# Ex 5.85(b):
# $$ V_{air} = 330\ L $$
# Ex 5.85(c):
# $$ \ce{C3H8(g) + 5O2(g) -> 3CO2(g) + 4H2O(l)} \qquad
#     \Delta H \rlap \degree _c = −2,219.2\ kJ/mol $$
# $$ \begin{align}
# \Delta H \rlap \degree _c &= \sum{n \cdot \Delta H \rlap \degree _f \text{ (products)}}-
#         \sum{n \cdot \Delta H \rlap \degree _f \text{ (reactants)}} \\[1ex]
# \Delta H \rlap \degree _c &= 3 \cdot \Delta H\rlap\degree_f\ [\ce{CO2(g)}] +
#         4 \cdot \Delta H\rlap\degree_f\ [\ce{H2O(l)}] -
#         \Delta H\rlap\degree_f\ [\ce{C3H8(g)}] \\[1ex]
# \Delta H\rlap\degree_f\ [\ce{C3H8(g)}] &= 3 \cdot \Delta H\rlap\degree_f\ [\ce{CO2(g)}]+
#         4 \cdot \Delta H\rlap\degree_f\ [\ce{H2O(l)}] -
#         \Delta H \rlap \degree _c \\[1ex]
# \Delta H\rlap\degree_f\ [\ce{C3H8(g)}] &= -104.5\ kJ/mol \\[1ex]
# \end{align} $$
# Ex 5.85(d):
# $$ \Delta T _{water} = 75.2 \degree C $$
#
# <strong style="color:red">Note:</strong> The book answer matched except for part (d), for which the book gave 75.4 &deg;C.  I do not see how to get that answer with different atomic weight sources.  I also tried rounding in one place, and that didn't recreate it either.  I will submit an errata.
