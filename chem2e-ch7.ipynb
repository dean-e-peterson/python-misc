# %% [markdown]
# # OpenStax Chemistry 2nd Ed. &ndash; Dean's Errata Submissions

# %% [markdown]
# **Execute this cell to display chemical formulas.**
# It contains a LaTeX require for mhchem, which even applies to later cells.
# $ \require{mhchem} $

# %% [markdown]
# # Chapter 7

# %% [markdown]
# ## Chapter 7 &ndash; Notes

# %% [markdown]
# \begin{align}
# \text{Hi Mom!} \\
# EN &:= \text{electronegativity (dimensionless and relative/approximate)} \\
# \Delta EN &:= \text{rough guide to expected polarity of bond} \\
# \\
# \newcommand{\D}{\mathrm{D}}
# \D &:= \text{bond energy (energy to break bond - consider average, not exact)} \\
# \D_{\ce{X-Y}} &= \Delta H \degree \text{ for } \ce{XY(g) -> X(g) + Y(g)} \\
# \Delta H_{\text{reaction}} &\approx
#     \sum{\D_{\text{bonds broken}}} -
#     \sum{\D_{\text{bonds formed}}} \\
# &\qquad\quad\text{\small{but prefer enthalpies of formation when available}} \\
# \Delta H \rlap \degree _{reaction} &=
#         \sum{n \cdot \Delta H \rlap \degree _f (\text{products})}
#         - \sum{n \cdot \Delta H \rlap \degree _f (\text{reactants})} \\
# \\
# \text{formal charge} &= \text{\# of valence electrons in free atom} \\
#     &- \text{\# of lone pair electrons} \\
#     &- 1/2 \text{ \# of bonding electrons (which equals \# of bonds)} \\
# \\
# \Delta H_{\text{lattice}} &:= \text{lattice energy} \\
# \Delta H_{\text{lattice}} &= \Delta H \text{ for } \ce{MX(s) -> M^{n+}(g) + X^{n-}(g)}\\
#     &= \frac{C(Z^+)(Z^-))}{R_o} \text{ (Coulomb related)} \\
# R_o &:= \text{interionic distance} = r_\text{positive ion} + r_\text{negative ion} \\
# \\
# \vec\mu &:= \text{bond dipole moment} \\
# \vec\mu &= Qr \\
# Q &:= \text{magnitude of partial charges (from electronegativity difference)} \\
# r &:= \text{distance between charges} \\
# \vec{\text{dipole moment}} &= \sum \vec\mu \text{ (sum bonds to get molecule)} \\
# \delta^+, \delta^- &:= \text{place on chemical structure to indicate partial charges}
# \end{align}

# %% [markdown]
# **cation** - Positive ion.
#
# **anion** - Negative ion.
#
# **ionic compound** - aka **salt**
# - Compound composed of ions
# - Electrons transferred
# - High electronegativity difference (often > 1.8)
# - Not molecular
# - **Common properties**
#   - When solid
#     - crystalline structure
#     - rigid and brittle
#     - ionic bonds are strong, so...
#     - high melting and boiling points
#     - poor electrical conductors - "ions" [electrons?] can't move
#     - dissolve in water
#   - Dissolved or melted
#     - good electrical and heat conductors - ions move freely
#
# - **Cation charge rules**
#     - Groups 1 and 2, same as group number
#     - Groups 13 through 17, group number minus 10, but also
#     - s valence electrons are first to go
#       - **inert pair effect** - Heavy ion s valence electron low energy can cause positive ions with two fewer positive charges than expected toward the bottom of groups 13, 14, and 15...and $\ce{Hg_2^{2+}}$.
#       - Transition metals 2+ or 3+ from losing valence s electrons and possibly a d electron.
#       - Inner transition metals 3+ from losing valence s electrons and a d or f electron.
#
# - **Anion charge rules**
#     - Take a non-metal, fill the s and p orbitals to get the same electron configuration as the next noble gas.
#
# **Covalent bond**
# - Electrons shared.
# - Atoms of similar attraction for electrons.
# - Polyatomic ions like $\ce{NH^4+}$ and $\ce{NO^3-}$ are held together covalently within themselves.
# - **Common properties**
#     - attraction weaker than ionic attraction, so...
#     - lower melting and boiling points
#     - softer when solid
#     - poor electrical conductors in any state
#     - do not dissolve in water
#
# - **Pure covalent bond**
#     - Electrons shared equally
#     - Low electronegativity difference (often < 0.4)
#     - Example: a bond between atoms of the same element
#
# - **Polar covalent bond**
#     - Electron (probability distributions) not shared equally, resulting in...
#     - Intermediate electronegativity difference (often 0.4 - 1.8)
#     - Partial positive/negative charges on the atoms
#
# **electronegativity** - Measure of an atom's tendency to attract electrons.
# - Increases left to right
# - Decreases down a group
# - Nobel gasses, group 18, excluded
# - Dimensionless
# - *arbitrary* or at least calculated, not measured, scale

# %% [markdown]
# **lone pairs** - Pairs of electrons not used in bonding.
#
# **Lewis symbol** - A element symbol surrounded by one dot for each valence electron.
# Like $ :\!\overset{\centerdot\centerdot}{\underset{\centerdot}{\ce{S}}}\,\cdot $
#
# **Lewis structure** - Diagrams showing bonding using Lewis symbols, like
# $
# :\!\overset{\centerdot\centerdot}{\underset{\centerdot\centerdot}{\ce{Cl}}}:
# \overset{\centerdot\centerdot}{\underset{\centerdot\centerdot}{\ce{Cl}}}:
# $
# or
# $
# :\!\overset{\centerdot\centerdot}{\underset{\centerdot\centerdot}{\ce{Cl}}}-
# \overset{\centerdot\centerdot}{\underset{\centerdot\centerdot}{\ce{Cl}}}:
# $
#
# **single bond** - Single pair of covalently shared electrons, like
# $
# :\!\overset{\centerdot\centerdot}{\underset{\centerdot\centerdot}{\ce{Cl}}}:
# \overset{\centerdot\centerdot}{\underset{\centerdot\centerdot}{\ce{Cl}}}:
# $
# or
# $
# :\!\overset{\centerdot\centerdot}{\underset{\centerdot\centerdot}{\ce{Cl}}}-
# \overset{\centerdot\centerdot}{\underset{\centerdot\centerdot}{\ce{Cl}}}:
# $
#
# **double bond** - Maybe like (guessing structure, recording notation)
# $
# :\!\overset{\centerdot}{\underset{\centerdot}{\ce{O}}}::
# \overset{\centerdot}{\underset{\centerdot}{\ce{O}}}:
# $
# or
# $
# :\!\overset{\centerdot}{\underset{\centerdot}{\ce{O}}}=
# \overset{\centerdot}{\underset{\centerdot}{\ce{O}}}:
# $
#
# **triple bond** - Like $ :\ce{C}:::\ce{O}: $
# or $ :\ce{C} \equiv \ce{O}: $
#
# **octet rule** - "tendency of main group atoms to form enough bonds to obtain 8 valence electrons"
#
# **octet rule exceptions**
# - **free radicals** - Molecules with an odd number of valence electrons.
# - Molecules that are electron-deficient, with a central atom having fewer electrons than a noble gas.  The central atom is usually group 2 or 13.  The outer atoms may be hydrogen.  Tend to be very reactive molecules.
# - Molecules that are hypervalent, with a central atom that has more electrons than a noble gas. Central atom from period >=3 using empty d orbitals in same shell.

# %% [markdown]
# **Lewis diagram steps from book**
# 1. Determine total number of valence electrons.
# 2. Place an atom with the lowest electronegativity in the center, and add single bonds to the other atoms.
# 3. Distribute remaining valence electrons as lone pairs to terminal atoms other than hydrogen.
# 4. Place remaining valence electrons around central atom.
# 5. Rearrange electrons of outer atoms to make double or triple bonds with the central atom to obtain octets.
# 6. Add any remaining electrons to the central atom (from section on hypervalent molecules.)

# %% [markdown]
# **formal charge** - "The formal charge of an atom in a molecule is the hypothetical charge the atom would have if we could redistribute the electrons in the bonds evenly between the atoms."  Not the actual charge, just a tool.  Sum to charge of molecule (0) or ion.
#
# \begin{align}
# \text{formal charge} &= \text{\# of valence electrons in free atom} \\
#     &- \text{\# of lone pair electrons} \\
#     &- 1/2 \text{ \# of bonding electrons (which equals \# of bonds)}
# \end{align}

# %% [markdown]
# **Choosing preferred Lewis diagram based on formal charges quoted from book**
# 1. "A molecular structure in which all formal charges are zero is preferable"
# 2. "the arrangement with the smallest nonzero formal charges is preferable."
# 3. "preferable when adjacent formal charges are zero or of the opposite sign."
# 4. "the structure with the negative formal charges on the more electronegative atoms is preferable."

# %% [markdown]
# **resonance** - "If two or more Lewis structures with the same arrangement of atoms can be written for a molecule or ion, the actual distribution of electrons is an average of that shown by the various Lewis structures."
#
# **resonance forms** - The individual Lewis structures being hybridized.  Not real.  (Dragon and unicorn.)
#
# **resonance hybrid** - The electronic structure averaging the forms.  Real.  (Rhinoceros.)
#
# $\boldsymbol{\longleftrightarrow}$ Resonance notation is a double headed arrow between Lewis diagrams.

# %% [markdown]
# **lattice energy** - $\Delta H_{\text{lattice}}$ - The energy required to separate one mole of a solid ionic compound into its component gaseous ions.
# - Positive, endothermic
# - larger means more stable
# - increases as ion charges increase (multiplicative, not additive, at least with 2 ion types)
# - increases as size of ions decrease
#
# *Note* - Some texts define lattice energy as energy released when the opposite reaction occurs, and therefore negative and exothermic.

# %% [markdown]
# **bond angle** - Angle between two bonds that include a common atom.
#
# **bond distance** aka **bond length** - distance between nuclei.
#
# **VSEPR theory** - Valence shell electron-pair repulsion theory - Approximately predicts molecular structure shape by considering repulsion between valence electron pairs, both bonded pairs and lone pairs.
#
# **Relative electron pair repulsion strengths**
#
# $$\text{bonding pair-bonding pair} < \text{lone pair-bonding pair} < \text{lone-pair lone-pair}$$
#
# $$ \text{single bond} < \text{double bond} < \text{triple bond} < \text{lone pair}$$
#
# **molecular structure** - locations of atoms (and bonds)
#
# **electron-pair geometry** - locations where electrons are located, including lone pairs not in molecular structure.
#
# **wedge and dash notation** - "solid lines represent bonds in the plane of the page, solid wedges represent bonds coming up out of the plane, and dashed lines represent bonds going down into the plane."
#
# Figure 7.16 from OpenStax Chemistry 2nd Ed.  Too much work to reproduce.
# ![image.png](attachment:a8a58bf5-ec2b-4eae-b8ea-43b8382b3c1f.png)
#
# Figure 7.19 from OpenStax Chemistry 2nd Ed.  Too much work to reproduce.
# ![image.png](attachment:2eefd74e-0855-493b-bb50-4841367593d3.png)

# %% [markdown]
# **bond dipole moment** - $\mu$ - From charge separation if electronegativity difference.  A vector.  Draw vector toward end with greater electronegativity.  Put a + sign on the *other* end of the vector to show charge direction.
#
# ![image.png](attachment:7f623e37-fc8c-49ee-a92a-342580d7e6f1.png)
#
# **dipole moment** - Net charge separation on whole molecule.  Vector sum of bond dipole moments.  Can be zero even with non-zero bond dipole moments if the bond dipole moments cancel out directionally.
#
# **polar molecule** aka dipole - Molecule with separation of charges.
# - Align themselves in a magnetic field.
# - Attracted to electrically charged objects.
# - Polar solvents are better at dissolving them.

# %% [markdown]
# ## Chapter 7 &ndash; Examples

# %% [markdown]
# ### Example 7.1 - Solution
# There are at least 14 elements categorized as “essential trace elements” for the human body. They are called “essential” because they are required for healthy bodily functions, “trace” because they are required only in small amounts, and “elements” in spite of the fact that they are really ions. Two of these essential trace elements, chromium and zinc, are required as Cr3+ and Zn2+. Write the electron configurations of these cations.

# %% [markdown]
# \begin{alignat}{2}  % equation columns (number of ampersands + 1) / 2
# &\ce{Cr}
#     &&= 1s^2 2s^2 2p^6 3s^2 3p^6 4s^1 3d^5 \text{ (Figure 6.29)} \\
# &
#     &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^5 4s^1  \text{ (reordered)} \\
# &\ce{Cr^{3+}}
#     &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^3 \\
# &\ce{Zn}
#     &&= 1s^2 2s^2 2p^6 3s^2 3p^6 4s^2 3d^{10} \\
# &
#     &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^{10} 4s^2 \\
# &\ce{Zn^{2+}}
#     &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^{10}
# &\end{alignat}
#
# Book used $[\ce{Ar}]$ abbreviation not full thing.

# %% [markdown]
# ### Example 7.1 - Check Your Learning
# Potassium and magnesium are required in our diet. Write the electron configurations of the ions expected from these elements.
# \begin{align}
# \ce{K^+} &= [\ce{Ar}] \\
# \ce{Mg^{2+}} &= \ce{[Ne]}
# \end{align}
# **Ooops** I had them switched.

# %% [markdown]
# ### Example 7.2 - Solution
# Selenium and iodine are two essential trace elements that form anions. Write the electron configurations of the anions.

# %% [markdown]
# \begin{align}
# \ce{Se} &= [\ce{Ar}] 4s^2 3d^{10} 4p^4 \\
# \ce{I} &= [\ce{Kr}] 5s^2 4d^{10} 5p^5 \\
# \\
# \ce{Se^{2-}} &= [\ce{Ar}] 4s^2 3d^{10} 4p^6 = [\ce{Kr}] \\
# \ce{I-} &= [\ce{Kr}] 5s^2 4d^{10} 5p^6 = [\ce{Xe}]
# \end{align}
# Book reverses the s and d subshells in the order they are written.

# %% [markdown]
# ### Example 7.2 - Check Your Learning
# Write the electron configurations of a phosphorus atom and its negative ion. Give the charge on the anion.

# %% [markdown]
# \begin{align}
# \ce{P} &: [\ce{Ne}] 3s^2 3p^3 \\
# \ce{P^{3-}} &: [\ce{Ne}] 3s^2 3p^6 = [\ce{Ar}]
# \end{align}

# %% [markdown]
# ### Example 7.3 - Solution
# Bond polarities play an important role in determining the structure of proteins. Using the electronegativity values in Figure 7.6, arrange the following covalent bonds—all commonly found in amino acids—in order of increasing polarity. Then designate the positive and negative atoms using the symbols δ+ and δ–:
# C–H, C–N, C–O, N–H, O–H, S–H

# %% [markdown]
# \begin{alignat}{2}
# &\Delta EN(\ce{C-H}) &&= -0.4 \\
# &\Delta EN(\ce{C-N}) &&= 0.5 \\
# &\Delta EN(\ce{C-O}) &&= 1 \\
# &\Delta EN(\ce{N-H}) &&= -0.9 \\
# &\Delta EN(\ce{O-H}) &&= -1.4 \\
# &\Delta EN(\ce{S-H}) &&= -0.4 \\
# \end{alignat}
# $$
# \Delta EN(\ce{\overset{\delta -}{C} - \overset{\delta +}{H}})
# = \Delta EN(\ce{\overset{\delta -}{S} - \overset{\delta +}{H}})
# < \Delta EN(\ce{\overset{\delta +}{C} - \overset{\delta -}{N}})
# < \Delta EN(\ce{\overset{\delta -}{N} - \overset{\delta +}{H}})
# < \Delta EN(\ce{\overset{\delta +}{C} - \overset{\delta -}{O}})
# < \Delta EN(\ce{\overset{\delta -}{O} - \overset{\delta +}{H}})
# $$

# %% [markdown]
# ### Example 7.3 - Check Your Learning
# Silicones are polymeric compounds containing, among others, the following types of covalent bonds: Si–O, Si–C, C–H, and C–C. Using the electronegativity values in Figure 7.6, arrange the bonds in order of increasing polarity and designate the positive and negative atoms using the symbols δ+ and δ–.

# %% [markdown]
# \begin{alignat}{2}
# &\Delta EN(\ce{Si-O}) &&= -1.7 \\
# &\Delta EN(\ce{Si-C}) &&= -0.7 \\
# &\Delta EN(\ce{C-H}) &&= 0.4 \\
# &\Delta EN(\ce{C-C}) &&= 0 \\
# \end{alignat}
# $$
# \Delta EN(\ce{\overset{\text{nonpolar}}{C - C}})
# < \Delta EN(\ce{\overset{\delta -}{C} - \overset{\delta +}{H}})
# < \Delta EN(\ce{\overset{\delta +}{Si} - \overset{\delta -}{C}})
# < \Delta EN(\ce{\overset{\delta +}{Si} - \overset{\delta -}{O}})
# $$
#
# Notation Note: I added an overset "nonpolar" to the C-C bond because that is the term the book used in its answer.  However, the book's answer was in table form, and an overset "nonpolar" was not used as a notation by the book in its anwer.

# %% [markdown]
# ### Example 7.4 - Solution
# NASA’s Cassini-Huygens mission detected a large cloud of toxic hydrogen cyanide (HCN) on Titan, one of Saturn’s moons. Titan also contains ethane (H3CCH3), acetylene (HCCH), and ammonia (NH3). What are the Lewis structures of these molecules?

# %% [markdown]
# ### Example 7.4 - Check Your Learning
# Both carbon monoxide, CO, and carbon dioxide, CO2, are products of the combustion of fossil fuels. Both of these gases also cause problems: CO is toxic and CO2 has been implicated in global climate change. What are the Lewis structures of these two molecules?

# %% [markdown]
# $\ce{HCN}$ has 10 valence electrons.
#
# $\ce{H3CCH3}$ has 14.
#
# $\ce{HCCH}$ has 10.
#
# $\ce{NH3}$ has 8.
#
# ---
# $\ce{CO}$ has 10 valence electrons.
#
# $\ce{CO2}$ has 16.

# %%
# %%SVG
# <svg xmlns="http://www.w3.org/2000/svg"
#      height="1000" width="450">
#     <defs>
#       <style>
#         .bg { fill: ghostwhite; }
#         .symbol { font-size: 25px; text-anchor: middle; }
#       </style>
#
#       <!-- miscellaneous -->
#       <symbol id="hrule" width="100%" height="2">
#         <line x1="0%" y1="50%" x2="100%" y2="50%" style="stroke: lightgray; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- dots, centered -->
#       <symbol id="dot1" width="50" height="50">
#         <circle cx="50%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="dot2h" width="50" height="50">
#         <circle cx="50%" cy="40%" r="6%" />
#         <circle cx="50%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="dot2v" width="50" height="50">
#         <circle cx="40%" cy="50%" r="6%" />
#         <circle cx="60%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- bonds, horizontal and vertical -->
#       <symbol id="b1h" width="50" height="50">
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b2h" width="50" height="50">
#         <line x1="35%" y1="45%" x2="65%" y2="45%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="55%" x2="65%" y2="55%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b3h" width="50" height="50">
#         <line x1="35%" y1="40%" x2="65%" y2="40%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="60%" x2="65%" y2="60%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b1v" width="50" height="50">
#         <line x1="50%" y1="35%" x2="50%" y2="65%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- Lewis dots, l for Lewis, then t r b l for top right botton left, then 1 or 2. -->
#       <symbol id="lt2" width="50" height="50"> <!-- top 2 -->
#         <circle cx="40%" cy="10%" r="6%" />
#         <circle cx="60%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr2" width="50" height="50"> <!-- right 2 -->
#         <circle cx="90%" cy="40%" r="6%" />
#         <circle cx="90%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lb2" width="50" height="50"> <!-- bottom 2 -->
#         <circle cx="40%" cy="90%" r="6%" />
#         <circle cx="60%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll2" width="50" height="50"> <!-- left 2 -->
#         <circle cx="10%" cy="40%" r="6%" />
#         <circle cx="10%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lt1" width="50" height="50"> <!-- top 1 -->
#         <circle cx="50%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr1" width="50" height="50"> <!-- right 1 -->
#         <circle cx="90%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="lb1" width="50" height="50"> <!-- bottom 1 -->
#         <circle cx="50%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll1" width="50" height="50"> <!-- left 1 -->
#         <circle cx="10%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- Lewis dots, combinations, number of them top, right, bottom, left -->
#       <symbol id="l1111" width="50" height="50">
#         <use href="#lt1"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2111" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2000" width="50" height="50">
#         <use href="#lt2"/>
#       </symbol>
#       <symbol id="l0200" width="50" height="50">
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l0020" width="50" height="50">
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2200" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l2020" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2022" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l2220" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#lb2"/>
#       </symbol>
#
#       <!-- Elements -->
#       <symbol id="H" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">H</text>
#       </symbol>
#       <symbol id="C" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">C</text>
#       </symbol>
#       <symbol id="N" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">N</text>
#       </symbol>
#       <symbol id="O" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">O</text>
#       </symbol>
#       <symbol id="Ne" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Ne</text>
#       </symbol>
#     </defs>
#
#     <!-- HCN -->
#     <use href="#H" x="0" y="0"/>
#     <use href="#b1h" x="25" y="0"/>
#     <use href="#C" x="50" y="0"/>
#     <use href="#b1h" x="75" y="0"/>
#     <use href="#N" x="100" y="0"/>
#
#     <use href="#H" x="0" y="100"/>
#     <use href="#b1h" x="25" y="100"/>
#     <use href="#C" x="50" y="100"/>
#     <use href="#b1h" x="75" y="100"/>
#     <use href="#N" x="100" y="100"/>
#     <use href="#l2220" x="100" y="100"/>
#
#     <!--
#     <use href="#H" x="0" y="200"/>
#     <use href="#dot2h" x="25" y="200"/>
#     <use href="#C" x="50" y="200"/>
#     <use href="#dot2h" x="70" y="200"/>
#     <use href="#dot2h" x="80" y="200"/>
#     <use href="#N" x="100" y="200"/>
#     <use href="#l2200" x="100" y="200"/>
#
#     <use href="#H" x="200" y="200"/>
#     <use href="#b1h" x="225" y="200"/>
#     <use href="#C" x="250" y="200"/>
#     <use href="#b2h" x="275" y="200"/>
#     <use href="#N" x="300" y="200"/>
#     <use href="#l2200" x="300" y="200"/>
#     -->
#
#     <use href="#H" x="0" y="200"/>
#     <use href="#dot2h" x="25" y="200"/>
#     <use href="#C" x="50" y="200"/>
#     <use href="#dot2h" x="65" y="200"/>
#     <use href="#dot2h" x="75" y="200"/>
#     <use href="#dot2h" x="85" y="200"/>
#     <use href="#N" x="100" y="200"/>
#     <use href="#l0200" x="100" y="200"/>
#
#     <use href="#H" x="200" y="200"/>
#     <use href="#b1h" x="225" y="200"/>
#     <use href="#C" x="250" y="200"/>
#     <use href="#b3h" x="275" y="200"/>
#     <use href="#N" x="300" y="200"/>
#     <use href="#l0200" x="300" y="200"/>
#
#     <use href="#hrule" x="0" y="275"/>
#
#     <use href="#H" x="50" y="300"/>
#     <use href="#b1v" x="50" y="325"/>
#     <use href="#H" x="0" y="350"/>
#     <use href="#b1h" x="25" y="350"/>
#     <use href="#H" x="50" y="400"/>
#     <use href="#b1v" x="50" y="375"/>
#     <use href="#C" x="50" y="350"/>
#     <use href="#b1h" x="75" y="350"/>
#     <use href="#C" x="100" y="350"/>
#     <use href="#H" x="100" y="300"/>
#     <use href="#b1v" x="100" y="325"/>
#     <use href="#H" x="150" y="350"/>
#     <use href="#b1h" x="125" y="350"/>
#     <use href="#H" x="100" y="400"/>
#     <use href="#b1v" x="100" y="375"/>
#
#     <use href="#hrule" x="0" y="475"/>
#
#     <use href="#H" x="0" y="500"/>
#     <use href="#b1h" x="25" y="500"/>
#     <use href="#C" x="50" y="500"/>
#     <use href="#l2000" x="50" y="500"/>
#     <use href="#b1h" x="75" y="500"/>
#     <use href="#C" x="100" y="500"/>
#     <use href="#l2000" x="100" y="500"/>
#     <use href="#H" x="150" y="500"/>
#     <use href="#b1h" x="125" y="500"/>
#
#     <use href="#H" x="0" y="600"/>
#     <use href="#dot2h" x="25" y="600"/>
#     <use href="#C" x="50" y="600"/>
#     <use href="#dot2h" x="65" y="600"/>
#     <use href="#dot2h" x="75" y="600"/>
#     <use href="#dot2h" x="85" y="600"/>
#     <use href="#C" x="100" y="600"/>
#     <use href="#H" x="150" y="600"/>
#     <use href="#dot2h" x="125" y="600"/>
#
#     <use href="#H" x="250" y="600"/>
#     <use href="#b1h" x="275" y="600"/>
#     <use href="#C" x="300" y="600"/>
#     <use href="#b3h" x="325" y="600"/>
#     <use href="#C" x="350" y="600"/>
#     <use href="#H" x="400" y="600"/>
#     <use href="#b1h" x="375" y="600"/>
#
#     <use href="#hrule" x="0" y="675"/>
#
#     <use href="#N" x="50" y="750"/>
#     <use href="#lb2" x="50" y="750"/>
#     <use href="#H" x="0" y="750"/>
#     <use href="#b1h" x="25" y="750"/>
#     <use href="#H" x="100" y="750"/>
#     <use href="#b1h" x="75" y="750"/>
#     <use href="#H" x="50" y="700"/>
#     <use href="#b1v" x="50" y="725"/>
#
#     <use href="#hrule" x="0" y="820"/>
#     <use href="#hrule" x="0" y="830"/>
#
#     <use href="#C" x="0" y="850"/>
#     <use href="#l2000" x="0" y="850"/>
#     <use href="#dot2h" x="15" y="850"/>
#     <use href="#dot2h" x="25" y="850"/>
#     <use href="#dot2h" x="35" y="850"/>
#     <use href="#O" x="50" y="850"/>
#     <use href="#l2000" x="50" y="850"/>
#
#     <use href="#C" x="150" y="850"/>
#     <use href="#l2000" x="150" y="850"/>
#     <use href="#b3h" x="175" y="850"/>
#     <use href="#O" x="200" y="850"/>
#     <use href="#l2000" x="200" y="850"/>
#
#     <use href="#hrule" x="0" y="925"/>
#
#     <use href="#O" x="0" y="950"/>
#     <use href="#l2020" x="0" y="950"/>
#     <use href="#dot2h" x="20" y="950"/>
#     <use href="#dot2h" x="30" y="950"/>
#     <use href="#C" x="50" y="950"/>
#     <use href="#dot2h" x="70" y="950"/>
#     <use href="#dot2h" x="80" y="950"/>
#     <use href="#O" x="100" y="950"/>
#     <use href="#l2020" x="100" y="950"/>
#
#     <use href="#O" x="200" y="950"/>
#     <use href="#l2020" x="200" y="950"/>
#     <use href="#b2h" x="225" y="950"/>
#     <use href="#C" x="250" y="950"/>
#     <use href="#b2h" x="275" y="950"/>
#     <use href="#O" x="300" y="950"/>
#     <use href="#l2020" x="300" y="950"/>
#
# </svg>

# %% [markdown]
# ### Exmaple 7.5 - Solution
# Xenon is a noble gas, but it forms a number of stable compounds. We examined XeF4 earlier. What are the Lewis structures of XeF2 and XeF6?
#
# $\ce{XeF2}$ has 22 valence electrons.
#
# $\ce{XeF6}$ has 50.

# %% [markdown]
# ### Example 7.5 - Check Your Learning
# The halogens form a class of compounds called the interhalogens, in which halogen atoms covalently bond to each other. Write the Lewis structures for the interhalogens BrCl3 and ICl4⁢−.
#
# $\ce{BrCl3}$ has 28 valence electrons.
#
# $\ce{ICl4-}$ has 36 (adding 1 for the - charge).

# %%
# %%SVG
# <svg xmlns="http://www.w3.org/2000/svg"
#      height="375" width="600">
#     <defs>
#       <style>
#         .bg { fill: ghostwhite; }
#         .symbol { font-size: 25px; text-anchor: middle; }
#       </style>
#
#       <!-- miscellaneous -->
#       <symbol id="hrule" width="100%" height="2">
#         <line x1="0%" y1="50%" x2="100%" y2="50%" style="stroke: lightgray; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- dots, centered -->
#       <symbol id="dot1" width="50" height="50">
#         <circle cx="50%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="dot2h" width="50" height="50">
#         <circle cx="50%" cy="40%" r="6%" />
#         <circle cx="50%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="dot2v" width="50" height="50">
#         <circle cx="40%" cy="50%" r="6%" />
#         <circle cx="60%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- bonds, horizontal vertical and diagnal (with north south east west -->
#       <symbol id="b1h" width="50" height="50">
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b2h" width="50" height="50">
#         <line x1="35%" y1="45%" x2="65%" y2="45%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="55%" x2="65%" y2="55%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b3h" width="50" height="50">
#         <line x1="35%" y1="40%" x2="65%" y2="40%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="60%" x2="65%" y2="60%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b1v" width="50" height="50">
#         <line x1="50%" y1="35%" x2="50%" y2="65%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b1dnwse" width="50" height="50">
#         <line x1="35%" y1="35%" x2="65%" y2="65%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- Lewis dots, l for Lewis, then t r b l for top right botton left, then 1 or 2. -->
#       <symbol id="lt2" width="50" height="50"> <!-- top 2 -->
#         <circle cx="40%" cy="10%" r="6%" />
#         <circle cx="60%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr2" width="50" height="50"> <!-- right 2 -->
#         <circle cx="90%" cy="40%" r="6%" />
#         <circle cx="90%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lb2" width="50" height="50"> <!-- bottom 2 -->
#         <circle cx="40%" cy="90%" r="6%" />
#         <circle cx="60%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll2" width="50" height="50"> <!-- left 2 -->
#         <circle cx="10%" cy="40%" r="6%" />
#         <circle cx="10%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lt1" width="50" height="50"> <!-- top 1 -->
#         <circle cx="50%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr1" width="50" height="50"> <!-- right 1 -->
#         <circle cx="90%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="lb1" width="50" height="50"> <!-- bottom 1 -->
#         <circle cx="50%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll1" width="50" height="50"> <!-- left 1 -->
#         <circle cx="10%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- Lewis dots, combinations, number of them top, right, bottom, left -->
#       <symbol id="l1111" width="50" height="50">
#         <use href="#lt1"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2111" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2000" width="50" height="50">
#         <use href="#lt2"/>
#       </symbol>
#       <symbol id="l0200" width="50" height="50">
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l0020" width="50" height="50">
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l0002" width="50" height="50">
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l0020" width="50" height="50">
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2200" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l2020" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2022" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l2220" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2202" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l0222" width="50" height="50">
#         <use href="#lr2"/>
#         <use href="#lb2"/>
#         <use href="#ll2"/>
#       </symbol>
#
#       <!-- Elements -->
#       <symbol id="F" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">F</text>
#       </symbol>
#       <symbol id="Xe" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Xe</text>
#       </symbol>
#       <symbol id="Br" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Br</text>
#       </symbol>
#       <symbol id="I" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">I</text>
#       </symbol>
#       <symbol id="Cl" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Cl</text>
#       </symbol>
#     </defs>
#
#     <!-- XeF2 -->
#     <use href="#F" x="0" y="50"/>
#     <use href="#l2022" x="0" y="50"/>
#     <use href="#b1h" x="25" y="50"/>
#     <use href="#Xe" x="50" y="50"/>
#     <use href="#l0020" x="50" y="50"/>
#     <use href="#l2000" x="50" y="50" transform="rotate(-35 75 75)"/>
#     <use href="#l2000" x="50" y="50" transform="rotate(35 75 75)"/>
#     <use href="#b1h" x="75" y="50"/>
#     <use href="#F" x="100" y="50"/>
#     <use href="#l2220" x="100" y="50"/>
#
#     <!-- XeF6 -->
#     <use href="#F" x="200" y="0"/>
#     <use href="#l2022" x="200" y="0" transform="rotate(45 225 25)"/>
#     <use href="#F" x="200" y="50"/>
#     <use href="#l2022" x="200" y="50"/>
#     <use href="#b1h" x="225" y="50"/>
#     <use href="#F" x="250" y="0"/>
#     <use href="#l2202" x="250" y="0"/>
#     <use href="#Xe" x="250" y="50"/>
#     <use href="#F" x="250" y="100"/>
#     <use href="#b1h" x="275" y="50"/>
#     <use href="#F" x="300" y="100"/>
#     <use href="#l2220" x="300" y="100" transform="rotate(45 325 125)"/>
#     <use href="#l2220" x="300" y="50"/>
#     <use href="#F" x="300" y="50"/>
#     <use href="#l0222" x="250" y="100"/>
#     <use href="#b1dnwse" x="225" y="25"/>
#     <use href="#b1dnwse" x="275" y="75"/>
#     <use href="#b1v" x="250" y="25"/>
#     <use href="#b1v" x="250" y="75"/>
#     <use href="#l2000" x="250" y="50" transform="rotate(45 275 75)"/>
#
#     <use href="#hrule" x="0" y="170"/>
#     <use href="#hrule" x="0" y="180"/>
#
#     <!-- BrCl3 -->
#     <use href="#Br" x="50" y="250" />
#     <use href="#Cl" x="0" y="250" />
#     <use href="#Cl" x="50" y="200" />
#     <use href="#Cl" x="100" y="250" />
#     <use href="#b1h" x="25" y="250" />
#     <use href="#b1h" x="75" y="250" />
#     <use href="#b1v" x="50" y="225" />
#     <use href="#l2022" x="0" y="250" />
#     <use href="#l2202" x="50" y="200" />
#     <use href="#l2220" x="100" y="250" />
#     <use href="#l0020" x="50" y="255" transform="rotate(-35 75 280)"/>
#     <use href="#l0020" x="50" y="255" transform="rotate(35 75 280)"/>
#
#     <!-- ICl4- -->
#     <use href="#I" x="250" y="250"/>
#     <use href="#Cl" x="200" y="250" />
#     <use href="#Cl" x="300" y="250" />
#     <use href="#Cl" x="250" y="200" />
#     <use href="#Cl" x="250" y="300" />
#     <use href="#b1h" x="225" y="250" />
#     <use href="#b1h" x="275" y="250" />
#     <use href="#b1v" x="250" y="225" />
#     <use href="#b1v" x="250" y="275" />
#     <use href="#l2022" x="200" y="250" />
#     <use href="#l2220" x="300" y="250" />
#     <use href="#l2202" x="250" y="200" />
#     <use href="#l0222" x="250" y="300" />
#     <use href="#l2000" x="250" y="250" transform="rotate(45 275 275)"/>
#     <use href="#l0020" x="250" y="250" transform="rotate(45 275 275)"/>
#     <path d="M210,195 L190,195 190,355 210,355" fill="none" stroke="black" stroke-width="2" />
#     <path d="M340,195 L360,195 360,355 340,355" fill="none" stroke="black" stroke-width="2" />
#     <line x1="375" y1="210" x2="385" y2="210" stroke="black" />
# </svg>

# %% [markdown]
# **Oops** - I forgot the brackets and minus sign until I saw the book answer.

# %% [markdown]
# ### Example 7.6 - Check Your Learning
# Calculate the formal charge for each atom in the carbon monoxide molecule: ![image.png](attachment:cafeba88-161c-4582-a864-e8d0a80b3a12.png)

# %% [markdown]
# 1. Splitting each bond gives C: 3 electrons, O: 3 electrons.
# 2. Adding lone pairs gives C: 5 electrons, O: 5 electrons.
# 3. Subtracting those counts from valence electron counts of neutral atoms gives C: (4 - 5) = -1 electron, O: (6 - 5) = 1 electron.
# Adding them gives 0, which is correct for a neutral atom like this.
#
# **Oops** I subtracted the wrong direction originally.

# %% [markdown]
# ### Example 7.7 - Solution
# Assign formal charges to each atom in the interhalogen molecule BrCl3.

# %% [markdown]
# Br = 7 - 4 - 3 = 0
#
# Cl = 7 - 6 - 1 = 0

# %% [markdown]
# ### Example 7.7 - Check Your Learning
# Determine the formal charge for each atom in NCl3.
#
# Valence electrons = 5 + 7 x 3 = 26

# %%
# %%SVG
# <svg xmlns="http://www.w3.org/2000/svg"
#      height="100" width="150">
#     <defs>
#       <style>
#         .bg { fill: ghostwhite; }
#         .symbol { font-size: 25px; text-anchor: middle; }
#       </style>
#
#       <!-- miscellaneous -->
#       <symbol id="hrule" width="100%" height="2">
#         <line x1="0%" y1="50%" x2="100%" y2="50%" style="stroke: lightgray; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- dots, centered -->
#       <symbol id="dot1" width="50" height="50">
#         <circle cx="50%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="dot2h" width="50" height="50">
#         <circle cx="50%" cy="40%" r="6%" />
#         <circle cx="50%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="dot2v" width="50" height="50">
#         <circle cx="40%" cy="50%" r="6%" />
#         <circle cx="60%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- bonds, horizontal vertical and diagnal (with north south east west -->
#       <symbol id="b1h" width="50" height="50">
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b2h" width="50" height="50">
#         <line x1="35%" y1="45%" x2="65%" y2="45%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="55%" x2="65%" y2="55%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b3h" width="50" height="50">
#         <line x1="35%" y1="40%" x2="65%" y2="40%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="60%" x2="65%" y2="60%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b1v" width="50" height="50">
#         <line x1="50%" y1="35%" x2="50%" y2="65%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b1dnwse" width="50" height="50">
#         <line x1="35%" y1="35%" x2="65%" y2="65%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- Lewis dots, l for Lewis, then t r b l for top right botton left, then 1 or 2. -->
#       <symbol id="lt2" width="50" height="50"> <!-- top 2 -->
#         <circle cx="40%" cy="10%" r="6%" />
#         <circle cx="60%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr2" width="50" height="50"> <!-- right 2 -->
#         <circle cx="90%" cy="40%" r="6%" />
#         <circle cx="90%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lb2" width="50" height="50"> <!-- bottom 2 -->
#         <circle cx="40%" cy="90%" r="6%" />
#         <circle cx="60%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll2" width="50" height="50"> <!-- left 2 -->
#         <circle cx="10%" cy="40%" r="6%" />
#         <circle cx="10%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lt1" width="50" height="50"> <!-- top 1 -->
#         <circle cx="50%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr1" width="50" height="50"> <!-- right 1 -->
#         <circle cx="90%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="lb1" width="50" height="50"> <!-- bottom 1 -->
#         <circle cx="50%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll1" width="50" height="50"> <!-- left 1 -->
#         <circle cx="10%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- Lewis dots, combinations, number of them top, right, bottom, left -->
#       <symbol id="l1111" width="50" height="50">
#         <use href="#lt1"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2111" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2000" width="50" height="50">
#         <use href="#lt2"/>
#       </symbol>
#       <symbol id="l0200" width="50" height="50">
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l0020" width="50" height="50">
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l0002" width="50" height="50">
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l0020" width="50" height="50">
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2200" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l2020" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2022" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l2220" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2202" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l0222" width="50" height="50">
#         <use href="#lr2"/>
#         <use href="#lb2"/>
#         <use href="#ll2"/>
#       </symbol>
#
#       <!-- Elements -->
#       <symbol id="F" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">F</text>
#       </symbol>
#       <symbol id="Xe" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Xe</text>
#       </symbol>
#       <symbol id="Br" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Br</text>
#       </symbol>
#       <symbol id="I" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">I</text>
#       </symbol>
#       <symbol id="Cl" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Cl</text>
#       </symbol>
#       <symbol id="H" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">H</text>
#       </symbol>
#       <symbol id="C" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">C</text>
#       </symbol>
#       <symbol id="N" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">N</text>
#       </symbol>
#       <symbol id="O" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">O</text>
#       </symbol>
#       <symbol id="Ne" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Ne</text>
#       </symbol>
#     </defs>
#
#     <!-- NCl3 (26 valence electrons) -->
#     <use href="#N" x="50" y="50"/>
#     <use href="#Cl" x="0" y="50"/>
#     <use href="#Cl" x="100" y="50"/>
#     <use href="#Cl" x="50" y="0"/>
#     <use href="#b1h" x="25" y="50"/>
#     <use href="#b1h" x="75" y="50"/>
#     <use href="#b1v" x="50" y="25"/>
#     <use href="#l2022" x="0" y="50" />
#     <use href="#l2202" x="50" y="0" />
#     <use href="#l2220" x="100" y="50" />
#     <use href="#l0020" x="50" y="50" />
#
# </svg>

# %% [markdown]
# N: 5 - 2 - 3 = 0
#
# Cl: 7 - 6 - 1 - 0

# %% [markdown]
# ### Example 7.8 - Solution
# Nitrous oxide, N2O, commonly known as laughing gas, is used as an anesthetic in minor surgeries, such as the routine extraction of wisdom teeth. Which is the more likely structure for nitrous oxide?
# ![image.png](attachment:97857d3f-2e5f-40e6-a051-e6e4a4401f54.png)

# %% [markdown]
# Hmm, formal charges are $\ce{\underset{0}{N} # \underset{+1}{N} - \underset{-1}{O}}$ and $\ce{\underset{-1}{N} = \underset{+2}{O} = \underset{-1}{N}}$.  Since the first option has lower formal charges and a less electronegative atom in the center, the first appears to be preferred.
#
# **Note:** The book adds a couple additional reasons, giving these...
# 1. "The number of atoms with formal charges are minimized"
# 2. "there is no formal charge with a magnitude greater than one"
# 3. "the negative formal charge is on the more electronegative element"
# 4. "the less electronegative atom is in the center position."

# %% [markdown]
# ### Exercise 7.8 - Check Your Learning
# Which is the most likely molecular structure for the nitrite (NO2⁢−) ion? ![image.png](attachment:963c1169-a789-413f-bed8-c6b6b52140cb.png)

# %% [markdown]
# Formal charges are $\ce{[\underset{-1}{N} = \underset{-2}{O} - \underset{-1}{O}]-}$ and $\ce{[\underset{0}{O} = \underset{+1}{N} - \underset{-1}{O}]-}$.  The second is preferable because:
# - Fewer atoms have non-zero formal charges.
# - The magnitudes of the formal charges are lower.
# - The central atom has less electronegativity.

# %% [markdown]
# ### Example 7.9 - Solution
# Methanol, CH3OH, may be an excellent alternative fuel. The high-temperature reaction of steam and carbon produces a mixture of the gases carbon monoxide, CO, and hydrogen, H2, from which methanol can be produced. Using the bond energies in Table 7.3, calculate the approximate enthalpy change, ΔH, for the reaction here:
#
# $\ce{CO⁡(g) +2⁢H2⁡(g)->CH3⁢OH⁡(g)}$

# %% [markdown]
# ```
# C ≡ O           H - H
#
#
#     H
#     |
# H - C - O - H
#     |
#     H
# ```

# %%
(1080 + 2 * 436) - (3 * 415 + 350 + 464)
# Out:
# -107

# %% [markdown]
# \begin{align}
# \Delta H &\approx \sum{\D_{broken}} - \sum{\D_{formed}} \\[.5ex]
#     &\approx (\D_\ce{C#O} + 2\ \D_\ce{H-H})
#         - (3\ \D_\ce{C-H} + \D_\ce{C-O} + \D_\ce{O-H}) \\[.5ex]
#     &\approx (1080 + 2 \cdot 436) - (3 \cdot 415 + 350 + 464)\ kJ/mol \\[.5ex]
#     &\approx -107\ kJ/mol
# \end{align}
#
# **Oops** - At first I used a single bond for CO.  Book compared with the more exact enthalpies of formation method, and got -90.5 kJ/mol, so not all that close.

# %% [markdown]
# ### Example 7.9 - Check Your Learning
# Ethyl alcohol, $\ce{CH3CH2OH}$, was one of the first organic chemicals deliberately synthesized by humans. It has many uses in industry, and it is the alcohol contained in alcoholic beverages. It can be obtained by the fermentation of sugar or synthesized by the hydration of ethylene in the following reaction:
#
# Using the bond energies in Table 7.3, calculate an approximate enthalpy change, ΔH, for this reaction.
#
# ![image.png](attachment:8656b2db-ed6d-4bef-b647-b35432607a9b.png)

# %%
(4 * 415 + 611) + (2 * 464) - (5 * 415 + 345 + 350 + 464)
# Out:
# -35

# %% [markdown]
# $$ \Delta H = -35\ kJ/mol$$

# %% [markdown]
# ### Example 7.10 - Solution
# The precious gem ruby is aluminum oxide, $\ce{Al2O3}$, containing traces of $\ce{Cr^{3+}}$. The compound $\ce{Al2Se3}$ is used in the fabrication of some semiconductor devices. Which has the larger lattice energy, $\ce{Al2O3}$ or $\ce{Al2Se3}$?

# %% [markdown]
# $\ce{Al2O3}$ has the larger lattice energy because the book pointed out the charges are the same, meaning the interionic distance will be the deciding factor, and Se is in same group as O but a later period.

# %% [markdown]
# ### Example 7.10 - Check Your Learning
# Zinc oxide, $\ce{ZnO}$, is a very effective sunscreen. How would the lattice energy of $\ce{ZnO}$ compare to that of $\ce{NaCl}$?

# %% [markdown]
# The lattice energy of $\ce{ZnO}$ would be larger than that of $\ce{NaCl}$ because the doubling of both charges multiplied would overcome any possible influence the other direction based on interionic distances.
#
# **Oh**, book said "interionic distance of ZnO is smaller than that of NaCl."

# %% [markdown]
# ### Example 7.11 - Solution
# Predict the electron-pair geometry and molecular structure for each of the following:
#
# (a) carbon dioxide, $\ce{CO2}$, a molecule produced by the combustion of fossil fuels
#
# (b) boron trichloride, $\ce{BCl3}$, an important industrial chemical

# %%
# %%SVG
# <svg xmlns="http://www.w3.org/2000/svg"
#      height="200" width="350">
#     <defs>
#       <style>
#         .bg { fill: ghostwhite; }
#         .symbol { font-size: 25px; text-anchor: middle; }
#       </style>
#
#       <!-- miscellaneous -->
#       <symbol id="hrule" width="100%" height="2">
#         <line x1="0%" y1="50%" x2="100%" y2="50%" style="stroke: lightgray; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- dots, centered -->
#       <symbol id="dot1" width="50" height="50">
#         <circle cx="50%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="dot2h" width="50" height="50">
#         <circle cx="50%" cy="40%" r="6%" />
#         <circle cx="50%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="dot2v" width="50" height="50">
#         <circle cx="40%" cy="50%" r="6%" />
#         <circle cx="60%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- bonds, horizontal and vertical -->
#       <symbol id="b1h" width="50" height="50">
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b2h" width="50" height="50">
#         <line x1="35%" y1="45%" x2="65%" y2="45%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="55%" x2="65%" y2="55%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b3h" width="50" height="50">
#         <line x1="35%" y1="40%" x2="65%" y2="40%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="60%" x2="65%" y2="60%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b1v" width="50" height="50">
#         <line x1="50%" y1="35%" x2="50%" y2="65%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- Lewis dots, l for Lewis, then t r b l for top right botton left, then 1 or 2. -->
#       <symbol id="lt2" width="50" height="50"> <!-- top 2 -->
#         <circle cx="40%" cy="10%" r="6%" />
#         <circle cx="60%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr2" width="50" height="50"> <!-- right 2 -->
#         <circle cx="90%" cy="40%" r="6%" />
#         <circle cx="90%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lb2" width="50" height="50"> <!-- bottom 2 -->
#         <circle cx="40%" cy="90%" r="6%" />
#         <circle cx="60%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll2" width="50" height="50"> <!-- left 2 -->
#         <circle cx="10%" cy="40%" r="6%" />
#         <circle cx="10%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lt1" width="50" height="50"> <!-- top 1 -->
#         <circle cx="50%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr1" width="50" height="50"> <!-- right 1 -->
#         <circle cx="90%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="lb1" width="50" height="50"> <!-- bottom 1 -->
#         <circle cx="50%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll1" width="50" height="50"> <!-- left 1 -->
#         <circle cx="10%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- Lewis dots, combinations, number of them top, right, bottom, left -->
#       <symbol id="l1111" width="50" height="50">
#         <use href="#lt1"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2111" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2000" width="50" height="50">
#         <use href="#lt2"/>
#       </symbol>
#       <symbol id="l0200" width="50" height="50">
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l0020" width="50" height="50">
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2200" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l2020" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2022" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l2220" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2202" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#ll2"/>
#       </symbol>
#
#       <!-- Elements -->
#       <symbol id="H" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">H</text>
#       </symbol>
#       <symbol id="B" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">B</text>
#       </symbol>
#       <symbol id="C" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">C</text>
#       </symbol>
#       <symbol id="N" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">N</text>
#       </symbol>
#       <symbol id="O" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">O</text>
#       </symbol>
#       <symbol id="Ne" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Ne</text>
#       </symbol>
#       <symbol id="Cl" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Cl</text>
#       </symbol>
#     </defs>
#
#     <!-- BCl3 (24 valence electrons) -->
#     <use href="#B" x="50" y="50"/>
#     <use href="#Cl" x="0" y="50"/>
#     <use href="#Cl" x="100" y="50"/>
#     <use href="#Cl" x="50" y="0"/>
#     <use href="#b1h" x="25" y="50"/>
#     <use href="#b1h" x="75" y="50"/>
#     <use href="#b1v" x="50" y="25"/>
#     <use href="#l2022" x="0" y="50" />
#     <use href="#l2202" x="50" y="0" />
#     <use href="#l2220" x="100" y="50" />
#
#     <use href="#hrule" x="0" y="125"/>
#
#     <!-- CO2 -->
#     <use href="#O" x="0" y="150"/>
#     <use href="#l2020" x="0" y="150"/>
#     <use href="#dot2h" x="20" y="150"/>
#     <use href="#dot2h" x="30" y="150"/>
#     <use href="#C" x="50" y="150"/>
#     <use href="#dot2h" x="70" y="150"/>
#     <use href="#dot2h" x="80" y="150"/>
#     <use href="#O" x="100" y="150"/>
#     <use href="#l2020" x="100" y="150"/>
#
#     <use href="#O" x="200" y="150"/>
#     <use href="#l2020" x="200" y="150"/>
#     <use href="#b2h" x="225" y="150"/>
#     <use href="#C" x="250" y="150"/>
#     <use href="#b2h" x="275" y="150"/>
#     <use href="#O" x="300" y="150"/>
#     <use href="#l2020" x="300" y="150"/>
#
# </svg>

# %% [markdown]
# Here is the book's description of the steps to use VSEPR theory:
#
# > The following procedure uses VSEPR theory to determine the electron pair geometries and the molecular structures:
# > -   Write the Lewis structure of the molecule or polyatomic ion.
# > -   Count the number of regions of electron density (lone pairs and bonds) around the central atom. A single, double, or triple bond counts as one region of electron density.
# > -   Identify the electron-pair geometry based on the number of regions of electron density: linear, trigonal planar, tetrahedral, trigonal bipyramidal, or octahedral (Figure 7.19, first column).
# > -   Use the number of lone pairs to determine the molecular structure (Figure 7.19). If more than one arrangement of lone pairs and chemical bonds is possible, choose the one that will minimize repulsions, remembering that lone pairs occupy more space than multiple bonds, which occupy more space than single bonds. In trigonal bipyramidal arrangements, repulsion is minimized when every lone pair is in an equatorial position. In an octahedral arrangement with two lone pairs, repulsion is minimized when the lone pairs are on opposite sides of the central atom.

# %% [markdown]
# $\ce{CO2}$
# 1. See above for Lewis structure.
# 2. 2 electron regions
# 3. Electron-pair geometry linear.
# 4. No lone pairs around central C atom, so molecular structure is basically the same linear structure.  **Note:** The book answer also mentioned the angle, 180 &deg;
# ```
#  O = C = O
# ```
#
# $\ce{BCl3}$
# 1. See above for Lewis structure.  **Note:** I only accidentally got the lack of a double bond in the Lewis diagram for $\ce{BCl3}$ correct.  The Boron is electron deficient (chapter 7.3), and is group 13 where the book suggests this might happen with group 2 and 13 central atoms.)
# 2. 3 electron regions.
# 3. Electron-pair geometry trigonal planar.
# 4. No lone pairs around central C atom, so molecular structure is basically the same trigonal planar structure. **Note:** The book answer also mentioned the angle, 120 &deg;, and drew the structure with one line, one solid wedge, and one dashed wedge, which seems unnecessarily fancy but fine.
# ```
#     Cl
#     |
#     B
#    / \
#  Cl   Cl
# ```

# %% [markdown]
# ### Example 7.11 - Check Your Learning
# Carbonate, $\ce{CO3^{⁢2−}}$, is a common polyatomic ion found in various materials from eggshells to antacids. What are the electron-pair geometry and molecular structure of this polyatomic ion?

# %%
# %%SVG
# <svg xmlns="http://www.w3.org/2000/svg"
#      height="175" width="300">
#     <defs>
#       <style>
#         .bg { fill: ghostwhite; }
#         .symbol { font-size: 25px; text-anchor: middle; }
#       </style>
#
#       <!-- miscellaneous -->
#       <symbol id="hrule" width="100%" height="2">
#         <line x1="0%" y1="50%" x2="100%" y2="50%" style="stroke: lightgray; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- dots, centered -->
#       <symbol id="dot1" width="50" height="50">
#         <circle cx="50%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="dot2h" width="50" height="50">
#         <circle cx="50%" cy="40%" r="6%" />
#         <circle cx="50%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="dot2v" width="50" height="50">
#         <circle cx="40%" cy="50%" r="6%" />
#         <circle cx="60%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- bonds, horizontal vertical and diagnal (with north south east west -->
#       <symbol id="b1h" width="50" height="50">
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b2h" width="50" height="50">
#         <line x1="35%" y1="45%" x2="65%" y2="45%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="55%" x2="65%" y2="55%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b3h" width="50" height="50">
#         <line x1="35%" y1="40%" x2="65%" y2="40%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="50%" x2="65%" y2="50%" style="stroke: black; stroke-width: 2px;" />
#         <line x1="35%" y1="60%" x2="65%" y2="60%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b1v" width="50" height="50">
#         <line x1="50%" y1="35%" x2="50%" y2="65%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#       <symbol id="b1dnwse" width="50" height="50">
#         <line x1="35%" y1="35%" x2="65%" y2="65%" style="stroke: black; stroke-width: 2px;" />
#       </symbol>
#
#       <!-- Lewis dots, l for Lewis, then t r b l for top right botton left, then 1 or 2. -->
#       <symbol id="lt2" width="50" height="50"> <!-- top 2 -->
#         <circle cx="40%" cy="10%" r="6%" />
#         <circle cx="60%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr2" width="50" height="50"> <!-- right 2 -->
#         <circle cx="90%" cy="40%" r="6%" />
#         <circle cx="90%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lb2" width="50" height="50"> <!-- bottom 2 -->
#         <circle cx="40%" cy="90%" r="6%" />
#         <circle cx="60%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll2" width="50" height="50"> <!-- left 2 -->
#         <circle cx="10%" cy="40%" r="6%" />
#         <circle cx="10%" cy="60%" r="6%" />
#       </symbol>
#       <symbol id="lt1" width="50" height="50"> <!-- top 1 -->
#         <circle cx="50%" cy="10%" r="6%" />
#       </symbol>
#       <symbol id="lr1" width="50" height="50"> <!-- right 1 -->
#         <circle cx="90%" cy="50%" r="6%" />
#       </symbol>
#       <symbol id="lb1" width="50" height="50"> <!-- bottom 1 -->
#         <circle cx="50%" cy="90%" r="6%" />
#       </symbol>
#       <symbol id="ll1" width="50" height="50"> <!-- left 1 -->
#         <circle cx="10%" cy="50%" r="6%" />
#       </symbol>
#
#       <!-- Lewis dots, combinations, number of them top, right, bottom, left -->
#       <symbol id="l1111" width="50" height="50">
#         <use href="#lt1"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2111" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr1"/>
#         <use href="#lb1"/>
#         <use href="#ll1"/>
#       </symbol>
#       <symbol id="l2000" width="50" height="50">
#         <use href="#lt2"/>
#       </symbol>
#       <symbol id="l0200" width="50" height="50">
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l0020" width="50" height="50">
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l0002" width="50" height="50">
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l0020" width="50" height="50">
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2200" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#       </symbol>
#       <symbol id="l2020" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2022" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lb2"/>
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l2220" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#lb2"/>
#       </symbol>
#       <symbol id="l2202" width="50" height="50">
#         <use href="#lt2"/>
#         <use href="#lr2"/>
#         <use href="#ll2"/>
#       </symbol>
#       <symbol id="l0222" width="50" height="50">
#         <use href="#lr2"/>
#         <use href="#lb2"/>
#         <use href="#ll2"/>
#       </symbol>
#
#       <!-- Elements -->
#       <symbol id="C" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">C</text>
#       </symbol>
#       <symbol id="O" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">O</text>
#       </symbol>
#       <symbol id="Br" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Br</text>
#       </symbol>
#       <symbol id="I" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">I</text>
#       </symbol>
#       <symbol id="Cl" width="50" height="50">
#         <text x="50%" y="66%" class="symbol">Cl</text>
#       </symbol>
#     </defs>
#
#     <!-- CO3 2+ (24 valence electrons) -->
#     <use href="#C" x="100" y="100"/>
#     <use href="#O" x="50" y="100"/>
#     <use href="#O" x="150" y="100"/>
#     <use href="#O" x="100" y="50"/>
#     <use href="#b1h" x="75" y="100"/>
#     <use href="#b2h" x="125" y="100"/>
#     <use href="#b1v" x="100" y="75"/>
#     <use href="#l2022" x="50" y="100" />
#     <use href="#l2202" x="100" y="50" />
#     <use href="#l2200" x="150" y="100" />
#
#     <path d="M60,45 L40,45 40,155 60,155" fill="none" stroke="black" stroke-width="2" />
#     <path d="M190,45 L210,45 210,155 190,155" fill="none" stroke="black" stroke-width="2" />
#     <!-- <line x1="225" y1="60" x2="235" y2="60" stroke="black" /> -->
#     <text x="225" y="65" style="font-size: 20px;">2+</text>
# </svg>

# %% [markdown]
# 1. $\ce{CO3^{2-}}$ has 24 valence electrons, (4 + 3 x 6) + 2, but I doubt its Lewis structure is electron deficient because C is not a group 2 or 13 element.  Therefore, see its Lewis structure above.  **Note:** Though I got the basic answer correct, I missed the fact that the Lewis structure would actually be a resonance of resonance forms where the double bond was in all three places.
# 2. Again, 3 bonds (one double, but still) and no lone pairs on the central atom give us 3 electron regions.
# 3. A trigonal planar electron pair geometry.
# 4. A trigonal planar molecular structure with angles of 120 &deg;.

# %% [markdown]
# ### Example 7.12 - Solution
# Two of the top 50 chemicals produced in the United States, ammonium nitrate and ammonium sulfate, both used as fertilizers, contain the ammonium ion. Predict the electron-pair geometry and molecular structure of the $\ce{NH4^+⁢}$ cation.

# %% [markdown]
# $\ce{NH4^+}$ valence electron count = 5 + 1 x 4 - 1 = 8
#
# The Lewis structure looks like this:
# <!-- made with Latex: \chemfig{\left[ \chemfig{N (-[:90]H) (<:[:190]H) (<[:235]H) -[:-20]H} \right]^+} -->
# ![image.png](attachment:e52cef21-0dde-462a-89fb-2c9f4f7c25da.png)
#
# The electron pair geometry and chemical structure are both tetrahedral.

# %% [markdown]
# ### Example 7.12 - Check Your Learning
# Identify a molecule with trigonal bipyramidal molecular structure.

# %% [markdown]
# Uhhh, $\ce{PF5}$ ?
#
# Ooo, that was what the book said was a common example.

# %% [markdown]
# ### Example 7.13 - Solution
# Predict the electron-pair geometry and molecular structure of a water molecule.

# %% [markdown]
# There are 8 valence electrons in $\ce{H2O}$.
#
# There are 4 electron regions on the central O atom.
#
# <!--
# \chemfig{O (<:[:120]\charge{[extra sep=5pt]90=\:}{})
#                      (<[:60]\charge{[extra sep=5pt]90=\:}{})
#                      (-[:-140]H)
#                      (-[:-40]H)}
#  -->
# ![image.png](attachment:51f90283-40f1-4e00-a043-7455728ce686.png)
#
# The electron pair geometry should be tetrahedral. **Oops,** I forgot to answer this part.
#
# The molecular structure should be bent with an angle significantly less than 109.5 &deg;.

# %% [markdown]
# ### Example 7.13 - Check Your Learning
# The hydronium ion, $\ce{H3O+}$, forms when acids are dissolved in water. Predict the electron-pair geometry and molecular structure of this cation.

# %% [markdown]
# There are 9 valence electrons.
#
# There are 5 electron regions.
#
# <!-- \chemfig{H - \charge{[circle]-135=\:,-45=\.}{O} (-[:90]H) - H} -->
#  ![image.png](attachment:2dfd90d7-c968-4ad5-b3a2-326bed925e2f.png)
#
# <!--
# \chemfig{O (<:[:160]\charge{[extra sep=5pt]160=\.}{})
#                      (<[:200]\charge{[extra sep=5pt]200=\:}{})
#                      (-[:90]H)
#                      (-[:0]H)
#                      (-[:-90]H)}
#  -->
# ![image.png](attachment:1808d241-e180-4b56-a81a-14c9266505f0.png)
#
# The electron pair geometry is trigonal bipyramid.
#
# But since the lone pair and lone electron go on two of the equatorial spots, the remaining three spots make a 90 &deg;, 90 &deg;, 180 &deg; T, so...
#
# The molecular structure is T-shaped.
#
# **AACK!** I messed up completely.  I forgot the +, so there are only 8 valence electrons and everything else I did was wrong.  Nuts.

# %% [markdown]
# **Try again**
#
# 8 valence electrons.
#
# 4 electron regions.
#
# <!-- $\left[ \chemfig{H - \charge{[circle]-90=\:}{O} (-[:90]H) - H} \right] ^+$ -->
#
# ![image.png](attachment:fccfbab6-6876-415f-a452-d7a7fa87c0da.png)
#
# <!--
# $\left[ \chemfig{O (-[:90]\charge{[extra sep=5pt]90=\:}{})
#                              (<:[:190]H)
#                              (<[:235]H)
#                              (-[:-20]H)} \right] ^+$
#  -->
#
# ![image.png](attachment:b42db8f7-f292-45d4-a55c-ecf52d17e67c.png)
#
# So the electron pair geometry is tetrahedral.
#
# The molecular structure is a trigonal pyramid.

# %% [markdown]
# ### Example 7.14 - Solution
# Sulfur tetrafluoride, $\ce{SF4}$, is extremely valuable for the preparation of fluorine-containing compounds used as herbicides (i.e., $\ce{SF4}$ is used as a fluorinating agent). Predict the electron-pair geometry and molecular structure of a $\ce{SF4}$ molecule.

# %% [markdown]
# Valence electron count is 6 + (4)(7) = 34.
#
# <!--
# \chemfig{ \charge{[circle]45=\:}{S}
#                 (-[:0]\charge{[circle]90=\:,0=\:,270=\:}{F})
#                 (-[:90]\charge{[circle]0=\:,90=\:,180=\:}{F})
#                 (-[:180]\charge{[circle]90=\:,180=\:,270=\:}{F})
#                  -[:270]\charge{[circle]0=\:,180=\:,270=\:}{F} }
#  -->
#
# The electron pair geometry is a trigonal bipyramid.
#
# ![image.png](attachment:c8238c78-393f-4874-ab66-8fe09ad44496.png)
#
# 4 regions are single bonds, and 1 is a lone pair, so the chemical structure shape is a "Sawhorse" or "Seesaw".
#
# <!--
# \chemfig{ S (-[:0]\charge{[extra sep=5pt]0=\:}{})
#                 (-[:90]F)
#                 (-[:-90]F)
#                 (<:[:155]F)
#                  <[:205]F }
#  -->
#
# ![image.png](attachment:980c6bbd-5d12-4957-bd8e-a1f0c11aa55e.png)

# %% [markdown]
# ### Example 7.14 - Check Your Learning
# Predict the electron pair geometry and molecular structure for molecules of $\ce{XeF2}$.

# %% [markdown]
# The valence electron count is 8 + (2)(7) = 22.
#
# <!--
# \chemfig{ \charge{[circle]50=\:,130=\:,270=\:}{Xe}
#                  (-[:0]\charge{[circle]90=\:,0=\:,270=\:}{F})
#                  (-[:180]\charge{[circle]90=\:,180=\:,270=\:}{F}) }
# -->
#
# ![image.png](attachment:357589b2-1d69-4416-8ab7-ab38509ebd43.png)
#
# So the electron pair geometry is trigonal bipyramidal.
#
# <!--
# \chemfig{ Xe (-[:0]\charge{[extra sep=5pt]0=\:}{})
#                  (<:[:155]\charge{[extra sep=5pt]155=\:}{})
#                  (<[:205]\charge{[extra sep=5pt]205=\:}{})
#                  (-[:90]F)
#                  (-[:-90]F)}
#  -->
#
# ![image.png](attachment:65c27958-0c25-44b5-9d90-5e7c10593747.png)
#
# The three lone pairs occupy the maximally separated equitorial spots, leaving the top and bottom for the real bonds.  In other words, the molecular structure is linear.

# %% [markdown]
# ### Example 7.15 - Solution
# Of all the noble gases, xenon is the most reactive, frequently reacting with elements such as oxygen and fluorine. Predict the electron-pair geometry and molecular structure of the $\ce{XeF4}$ molecule.

# %% [markdown]
# The valence electron count is 8 + (4)(7) = 36.
#
# <!--
# \chemfig{ \charge{[circle]90=\:,270=\:}{Xe}
#                  (-[:0]\charge{[circle]90=\:,0=\:,270=\:}{F})
#                  (-[:135]\charge{[circle]0=\:,90=\:,180=\:}{F})
#                  (-[:180]\charge{[circle]90=\:,180=\:,270=\:}{F})
#                  (-[:315]\charge{[circle]180=\:,270=\:,0=\:}{F}) }
#  -->
#
# ![image.png](attachment:eac40449-51d5-48c5-b38d-019e2af03fb7.png)
#
# So the \ce{Xe} atom has 6 electron regions.  This means the electron pair geometry is a octahedral.
#
# <!--
# \chemfig{ Xe (-[:90]\charge{[extra sep=5pt]90=\:}{})
#                  (-[:270]\charge{[extra sep=5pt]270=\:}{})
#                  (<:[:155]F)
#                  (<[:205]F)
#                  (<:[:25]F)
#                  (<[:335]F) }
#  -->
#
# ![image.png](attachment:1fe0e973-ff7a-4f8b-af1f-3607a06774d6.png)
#
# 2 regions are single bonds, and 4 are lone pairs.
# This means the chemical structure shape is square planar.

# %% [markdown]
# ### Example 7.15 - Check Your Learning
# In a certain molecule, the central atom has three lone pairs and two bonds. What will the electron pair geometry and molecular structure be?

# %% [markdown]
# The electron pair geometry with 5 regions will be trigonal pyramidal.
#
# The molecular structure will the Linear.
# **Oops,** I originally messed it up and said T-shaped.

# %% [markdown]
# ### Example 7.16 - Solution
# The Lewis structure for the simplest amino acid, glycine, $\ce{H2NCH2CO2H}$, is shown here. Predict the local geometry for the nitrogen atom, the two carbon atoms, and the oxygen atom with a hydrogen atom attached:
#
# ![image.png](attachment:b5e87940-af33-44c0-be9a-2e16024d4ce8.png)

# %% [markdown]
# N - tetrahedral electron pair geometry, trigonal pyramid molecule shape.
#
# C(1) - tetrahedral electron pair geometry, tetrahedral molecule shape.
#
# C(2) bonded to Os - trigonal planar electron pair geometry, trigonal planar molecule shape.
#
# O with H - tetrahedral electron pair geometry, bent or "angular" molecule shape.
#
# Note that I didn't give a 3-D diagram, but the book did:
#
# ![image.png](attachment:d31e39a1-6859-4f4d-abc3-3a420b201c5c.png)

# %% [markdown]
# ### Example 7.16 - Check Your Learning
# Another amino acid is alanine, which has the Lewis structure shown here. Predict the electron-pair geometry and local structure of the nitrogen atom, the three carbon atoms, and the oxygen atom with hydrogen attached:
#
# ![image.png](attachment:609c6d0e-859c-4b3c-82dd-0b39dd949572.png)

# %% [markdown]
# | Atom | Electron Pair Geometry | Local Structure |
# |-|-|-|
# | N | Tetrahedral | Trigonal Pyramid |
# | C(1 bottom left) | Tetrahedral | Tetrahedral |
# | C(2 CH3) | Tetrahedral | Tetrahedral |
# | C(3 right) | Trigonal Planar | Trigonal Planar |
# | O(with H) | Tetrahedral | Bent (**book** says 109&deg;) |

# %% [markdown]
# ### Example 7.17 - Solution
# Using molecular shape simulator allows us to control whether bond angles and/or lone pairs are displayed by checking or unchecking the boxes under “Options” on the right. We can also use the “Name” checkboxes at bottom-left to display or hide the electron pair geometry (called “electron geometry” in the simulator) and/or molecular structure (called “molecular shape” in the simulator).
#
# Build the molecule HCN in the simulator based on the following Lewis structure:
#
# $$\ce{H – C # N}$$
#
# Click on each bond type or lone pair at right to add that group to the central atom. Once you have the complete molecule, rotate it to examine the predicted molecular structure. What molecular structure is this?

# %% [markdown]
# Linear
#
# ![image.png](attachment:8f7f6a7a-9161-4edb-83ac-705fb582cb50.png)

# %% [markdown]
# ### Example 7.17 - Check Your Learning
# Build a more complex molecule in the simulator. Identify the electron-group geometry, molecular structure, and bond angles. Then try to find a chemical formula that would match the structure you have drawn.

# %% [markdown]
# $\ce{NH3}$, ammonia, would, I believe, have an electron geometry of tetrahedral and a molecular geometry of trigonal pyramidal.
#
# ![image.png](attachment:dff6fcc5-a52f-4903-84b7-00e68330b41e.png)

# %% [markdown]
# ### Example 7.18 - Solution
# Open the molecule polarity simulation and select the “Three Atoms” tab at the top. This should display a molecule ABC with three electronegativity adjustors. You can display or hide the bond moments, molecular dipoles, and partial charges at the right. Turning on the Electric Field will show whether the molecule moves when exposed to a field, similar to Figure 7.28.
#
# Use the electronegativity controls to determine how the molecular dipole will look for the starting bent molecule if:
#
# (a) A and C are very electronegative and B is in the middle of the range.
#
# (b) A is very electronegative, and B and C are not.

# %% [markdown]
# (a) The molecular dipole vector is fairly long and its negative arrowhead points to the inside of the bend, between the outer atoms.
#
# ![image.png](attachment:8d9f2b37-2f8a-4158-9865-17b893efd1bc.png)

# %% [markdown]
# (b) The molecule's dipole moment vector's negative arrowhead points along the axis of the central molecule's bond with the very electronegative A molecule, in the direction of the A molecule.
#
# ![image.png](attachment:2bd88ed7-4b60-4a3f-a291-6af5556ffff2.png)

# %% [markdown]
# ### Example 7.18 - Check Your Learning
# Determine the partial charges that will give the largest possible bond dipoles.

# %% [markdown]
# The largest bond dipoles are with partial charges of the opposite sign and greatest magnitudes on either end of the bond.

# %% [markdown]
# ## Chapter 7 &ndash; Exercises

# %% [markdown]
# ### Exercise 7.1
# Does a cation gain protons to form a positive charge or does it lose electrons?

# %% [markdown]
# It loses electrons.

# %% [markdown]
# ### Exercise 7.2
# Iron(III) sulfate $\ce{[Fe2(SO4)3]}$ is composed of $\ce{Fe^{3+}}$ and $\ce{SO4^{⁢2−}}$ ions. Explain why a sample of iron(III) sulfate is uncharged.

# %% [markdown]
# It is uncharged because the positive and negative charges exactly cancel out. This can be seen by noting that for every 2 $\ce{Fe^{3+}}$ ions there are 3 $\ce{SO4^{⁢2−}}$ ions.  The 2 $\ce{Fe^{3+}}$ ions have a charge of 2 x 3 = 6, while the 3 $\ce{SO4^{⁢2−}}$ ions have a charge of 3 x (-2) = -6, so they exactly cancel.
#
# Oops, I accidentally did an even numbered exercise for which I don't have a book answer.  Oh well.

# %% [markdown]
# ### Exercise 7.3
# Which of the following atoms would be expected to form negative ions in binary ionic compounds and which would be expected to form positive ions: P, I, Mg, Cl, In, Cs, O, Pb, Co?

# %% [markdown]
# Negative (-): P, I, Cl, O
#
# Positive (+): Mg, In, Cs, Pb, Co

# %% [markdown]
# ### Exercise 7.5
# Predict the charge on the monatomic ions formed from the following atoms in binary ionic compounds:
#
# (a) P - 3-
#
# (b) Mg - 2+
#
# (c) Al - 3+
#
# (d) O - 2-
#
# (e) Cl - 1-
#
# (f) Cs - 1+

# %% [markdown]
# ### Exercise 7.7
# Write the electron configuration for each of the following ions:
#
# (a) As3–: $[Kr] = [Ar] 4s^2 3d^{10} 4p^6$
#
# (b) I–: $[Xe] = [Kr] 5s^2 4d^{10} 5p^6$
#
# (c) Be2+: $[He]$
#
# (d) Cd2+: $[Kr] 4d^{10}$
#
# (e) O2–: $[Ne] = [He] 2s^2 2p^6$
#
# (f) Ga3+: $[Ar] 3d^{10}$
#
# (g) Li+: $[He]$
#
# (h) N3–: $[Ne]$
#
# (i) Sn2+: $[Kr] 4d^{10} 5s^2$
#
# (j) Co2+: $[Ar] 4s^2 3d^5$ <strong style="color:red">&nbsp;Oops,</strong> $\color{red}{[Ar] 3d^7}$
#
# (k) Fe2+: $[Ar] 4s^1 3d^5$ <strong style="color:red">&nbsp;Oops,</strong> $\color{red}{[Ar] 3d^6}$
#
# (l) As3+: $[Ar] 4s^2 3d^{10}$
#
# **Note:** In addition to the two I got wrong, the book answers always had at least one period's worth of orbital details, and never just, for example, [Ne].

# %% [markdown]
# ### Exercise 7.9
# Write out the full electron configuration for each of the following atoms and for the monatomic ion found in binary ionic compounds containing the element:
#
# (a) Al
#
# (b) Br
#
# (c) Sr
#
# (d) Li
#
# (e) As
#
# (f) S

# %% [markdown]
# \begin{alignat}{3}
# &(a)& \  & \ce{Al} &&= [Ne] 3s^2 3p^1 &&= 1s^2 2s^2 2p^6 3s^2 3p^1 \\
# &   &    & \ce{Al^{3+}} &&= [Ne] &&= 1s^2 2s^2 2p^6 3s^2 3p^6 \quad \color{red}{\textbf{Oops: } 1s^2 2s^2 2p^6} \\
# &(b)& \  & \ce{Br} &&= [Ar] 3d^{10} 4s^2 4p^5 &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^{10} 4s^2 4p^5 \\
# &   &    & \ce{Br^{-}} &&= [Kr] &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^{10} 4s^2 4p^6 \\
# &(c)& \  & \ce{Sr} &&= [Kr] 5s^2 &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^{10} 4s^2 4p^6 5s^2 \\
# &   &    & \ce{Sr^{2+}} &&= [Kr] &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^{10} 4s^2 4p^6 \\
# &(d)& \  & \ce{Li} &&= [He] 2s^1 &&= 1s^2 2s^1 \\
# &   &    & \ce{Li^{+}} &&= [He] &&= 1s^2 \\
# &(e)& \  & \ce{As} &&= [Ar] 3d^{10} 4s^2 4p^3 &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^{10} 4s^2 4p^3 \\
# &   &    & \ce{As^{3-}} &&= [Kr] &&= 1s^2 2s^2 2p^6 3s^2 3p^6 3d^{10} 4s^2 4p^6 \\
# &(f)& \  & \ce{S} &&=  [Ne] 3s^2 3p^4 &&= 1s^2 2s^2 2p^6 3s^2 3p^4 \\
# &   &    & \ce{S^{2-}} &&=  [Ar] &&= 1s^2 2s^2 2p^6 3s^2 3p^6 \\
# \end{alignat}

# %% [markdown]
# ### Exercise 7.11
# Why is it incorrect to speak of a molecule of solid NaCl?

# %% [markdown]
# Because, as an ionic solid, NaCl forms a lattice of ions where any particular ion attracts all the oppositely charged ions around it.  It other words, each ion is not paired with one particular other ion to the exclusion of all others around it.
#
# **Note:** Book answer also mentioned they are not covalently bonded molecules.

# %% [markdown]
# ### Exercise 7.13
# Predict which of the following compounds are ionic and which are covalent, based on the location of their constituent atoms in the periodic table:
#
# (a) Cl2CO - covalent
#
# (b) MnO - ionic
#
# (c) NCl3 - covalent
#
# (d) CoBr2 - covalent <strong style="color:red">&nbsp;Oops: ionic</strong>
#
# (e) K2S - ionic
#
# (f) CO - covalent
#
# (g) CaF2 - ionic
#
# (h) HI - covalent
#
# (i) CaO - ionic
#
# (j) IBr - covalent
#
# (k) CO2 - covalent

# %% [markdown]
# ### Exercise 7.15
# From its position in the periodic table, determine which atom in each pair is more electronegative:
#
# (a) Br or Cl - Cl
#
# (b) N or O - O
#
# (c) S or O - O
#
# (d) P or S - S
#
# (e) Si or N - N
#
# (f) Ba or P - P
#
# (g) N or K - N

# %% [markdown]
# ### Exercise 7.17
# From their positions in the periodic table, arrange the atoms in each of the following series in order of increasing electronegativity:
#
# (a) C, F, H, N, O - H < C < N < O < F
#
# (b) Br, Cl, F, H, I - H < I < Br < Cl < F
#
# (c) F, H, O, P, S - H < P < S < O < F
#
# (d) Al, H, Na, O, P - Na < H < Al < P < O  <strong style="color:red">&nbsp;Oops: Na < Al < H < P < O</strong>
#
# (e) Ba, H, N, O, As - Ba < H < As < N < O
#
# **Note:** I should have looked up the electronegativity values, instead of guessing based on periodic table position alone.

# %% [markdown]
# ### Exercise 7.19
# Which atoms can bond to sulfur so as to produce a positive partial charge on the sulfur atom?

# %% [markdown]
# Cl, O, F  <strong style="color:red">&nbsp;Oops: Also N</strong>
#
# **Note:** I should have looked up the electronegativity values.

# %% [markdown]
# ### Exercise 7.21
# Identify the more polar bond in each of the following pairs of bonds:
#
# (a) HF or HCl - HF
#
# (b) NO or CO - CO
#
# (c) SH or OH - OH
#
# (d) PCl or SCl - SCl <strong style="color:red">&nbsp;Oops: PCl</strong> (dumb of me)
#
# (e) CH or NH - NH
#
# (f) SO or PO - PO
#
# (g) CN or NN - CN

# %% [markdown]
# ### Exercise 7.23
# Write the Lewis symbols for each of the following ions:
#
# (a) As3–
#
# (b) I–
#
# (c) Be2+
#
# (d) O2–
#
# (e) Ga3+
#
# (f) Li+
#
# (g) N3–

# %% [markdown]
# My answers, <strong style="color:red">Oops:</strong> book answers
# <!--
# \begin{enumerate}
# \item
#     $\left[\;
#     \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{As}}
#     \;\right]^{3-}$
# \item
#     $\left[\;
#     \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{I}}
#     \;\right]^{–}$
# \item
#     $\left[\;
#     \chemfig{\charge{[circle]0=\:}{Be}}
#     \;\right]^{2+}$
# \item
#     $\left[\;
#     \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{O}}
#     \;\right]^{2–}$
# \item
#     $\left[\;
#     \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:,315=\:}{Ga}}
#     \;\right]^{3+}$
# \item
#     $\left[\;
#     \chemfig{\charge{[circle]0=\:}{Li}}
#     \;\right]^{+}$
# \item
#     $\left[\;
#     \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{N}}
#     \;\right]^{3–}$
# \end{enumerate}
#
# % book answers
# \begin{enumerate}
#     \item
#         \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{As}^{3-}}
#     \item
#         \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{I}\enspace^{–}}
#     \item
#         \chemfig{Be^{2+}}
#     \item
#         $\chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{O}}\;\,^{2–}$
#     \item
#         $\chemfig{Ga}^{3+}$
#     \item
#         \chemfig{Li^+}
#     \item
#         $\chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{N}}\;\,^{3–}$
# \end{enumerate}
# -->
# ![image.png](attachment:e2007e76-5879-4eb3-925e-1ee6d6ec858a.png)
# ![image.png](attachment:4a0db31f-21b1-44d8-954e-f27db00ee2ec.png)

# %% [markdown]
# ### Exercise 7.25
# Write the Lewis symbols of the ions in each of the following ionic compounds and the Lewis symbols of the atom from which they are formed:
#
# (a) MgS
#
# (b) Al2O3
#
# (c) GaCl3
#
# (d) K2O
#
# (e) Li3N
#
# (f) KF

# %% [markdown]
# <!--
# \begin{enumerate}
#
# \item MgS \quad\enspace
# \chemfig{Mg^{2+}} \quad
# \chemfig{\charge{[circle]0=\:}{Mg}} \qquad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{S}\,\,^{2-}} \quad
# \chemfig{\charge{[circle]0=\:,90=\:,270=\:}{S}} \quad
#
# \item Al2O3 \quad
# \chemfig{Al^{3+}} \quad
# \chemfig{\charge{[circle]0=\:,180=\.}{Al}} \qquad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{O}\,\,^{2-}} \quad
# \chemfig{\charge{[circle]0=\:,90=\:,270=\:}{O}} \quad
#
# \item GaCl3 \quad
# \chemfig{Ga^{3+}} \quad
# \chemfig{\charge{[circle]0=\:,180=\.}{Ga}} \qquad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{Cl}\,\,^{-}} \quad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\.,270=\:}{Cl}} \quad
#
# \item K2O \qquad
# \chemfig{K^{+}} \quad
# \chemfig{\charge{[circle]0=\.}{K}} \qquad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{O}\,\,^{2-}} \quad
# \chemfig{\charge{[circle]0=\:,90=\:,270=\:}{O}} \quad
#
# \item Li3N \qquad
# \chemfig{Li^{+}} \quad
# \chemfig{\charge{[circle]0=\.}{Li}} \qquad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{N}\,\,^{3-}} \quad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\.}{N}} \quad
#
# \item KF \qquad\enspace
# \chemfig{K^{+}} \quad
# \chemfig{\charge{[circle]0=\.}{K}} \qquad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\:,270=\:}{F}\,\,^{-}} \quad
# \chemfig{\charge{[circle]0=\:,90=\:,180=\.,270=\:}{F}} \quad
#
# \end{enumerate}
#  -->
#
# ![image.png](attachment:d1bd8829-9ff1-4194-a8ff-62c1ccd320ff.png)

# %% [markdown]
# ### Exercise 7.27
# Write the Lewis structure for the diatomic molecule P2, an unstable form of phosphorus found in high-temperature phosphorus vapor.

# %% [markdown]
# <!--
# \begin{itemize}
#     \item Write the molecule with a single bond. \\
#         \chemfig{P - P}
#     \item Add valence electrons. \\
#         \chemfig{\charge{[circle]90=\:,270=\:}{P} -
#                  \charge{[circle]90=\:,270=\:}{P}}
#     \item Use multiple bonds to try for octets. \\
#         \chemfig{\charge{[circle]90=\:}{P} ~
#                  \charge{[circle]90=\:}{P}}
# \end{itemize}
#  -->
#
# ![image.png](attachment:37b836f2-00e9-40b4-ba7d-467d2fb83041.png)

# %% [markdown]
# ### Exercise 7.29
# Write Lewis structures for the following:
#
# (a) O2
#
# (b) H2CO
#
# (c) AsF3
#
# (d) ClNO
#
# (e) SiCl4
#
# (f) H3O+
#
# (g) NH4⁢+
#
# (h) BF4⁢−
#
# (i) HCCH
#
# (j) ClCN
#
# (k) C2⁢2+

# %% [markdown]
# <!--
# \begin{enumerate}
#
# \item \ce{O2}: \quad
# \chemfig{\charge{[circle]90=\:,270=\:}{O} =
#          \charge{[circle]90=\:,270=\:}{O}}
#
# \item \ce{H2CO}: \quad
# \chemfig{C (-[:90]H) (-[:270]H) = \charge{[circle]90=\:,270=\:}{O}}
#
# \item \ce{AsF3}: \quad
# \chemfig{\charge{[circle]270=\:}{As}
#          (-[:180]\charge{[circle]-90=\:,180=\:,90=\:}{F})
#          (-[:90]\charge{[circle]0=\:,180=\:,90=\:}{F})
#          (-[:0]\charge{[circle]-90=\:,0=\:,90=\:}{F})}
#
# \item \ce{ClNO}: \quad
# \chemfig{\charge{[circle]-90=\:,180=\:,90=\:}{Cl} -
#          \charge{[circle]-90=\:}{N} =
#          \charge{[circle]-90=\:,90=\:}{O}}
#
# \item \ce{SiCl4}: \quad
# \chemfig{Si
#          (-[:0]\charge{[circle]-90=\:,0=\:,90=\:}{Cl})
#          (-[:90]\charge{[circle]0=\:,180=\:,90=\:}{Cl})
#          (-[:180]\charge{[circle]-90=\:,180=\:,90=\:}{Cl})
#          (-[:270]\charge{[circle]-90=\:,180=\:,0=\:}{Cl})}
#
# \item \ce{H3O^{+}}: \quad
# $\left[
# \chemfig{\charge{[circle]270=\:}{O}
#     (-[:180]H)
#     (-[:90]H)
#     (-[:0]H)}
# \right]^+$
#
# \item \ce{NH4+} : \quad
# $\left[
# \chemfig{N
#     (-[:0]H)
#     (-[:90]H)
#     (-[:180]H)
#     (-[:270]H)}
# \right]^+$
#
# \item \ce{BF4-}: \quad
# $\left[\;
# \chemfig{B
#     (-[:0]\charge{[circle]-90=\:,0=\:,90=\:}{F})
#     (-[:90]\charge{[circle]0=\:,180=\:,90=\:}{F})
#     (-[:180]\charge{[circle]-90=\:,180=\:,90=\:}{F})
#     (-[:270]\charge{[circle]-90=\:,180=\:,0=\:}{F})}
# \;\right]^-$
#
# \item \ce{HCCH}: \quad
# \chemfig{H - C ~ C - H}
#
# \item \ce{ClCN}: \quad
# \chemfig{\charge{[circle]-90=\:,90=\:}{Cl} =
#          C =
#          \charge{[circle]-90=\:,90=\:}{N}}
#
# \item \ce{C2^{2+}}: \quad
# $\left[\,
# \chemfig{C ~ C}
# \,\right]^{2+}$
#
# \end{enumerate}
#  -->
#
# ![image.png](attachment:05e5969e-4f90-479d-b5d0-459e9081ac61.png)
#
# ![image.png](attachment:6cb3bde5-dc84-4002-ab8d-cdaf04bfba23.png)
#
# ![image.png](attachment:86f62979-84ef-44ac-b9f0-29abc42a475d.png)
#
# ![image.png](attachment:477433ab-063e-4fb3-9d97-4b5c28ea733b.png)
#
# <strong style="color:red">Oops:</strong> Book answer for $\ce{ClCN}$ is
#
# ![image.png](attachment:8e1292e5-33e1-4f48-8a02-edb8872a2665.png)

# %% [markdown]
# ### Exercise 7.31
# Write Lewis structures for the following:
#
# (a) SeF6
#
# (b) XeF4
#
# (c) SeCl3⁢+
#
# (d) Cl2BBCl2 (contains a B–B bond)

# %% [markdown]
# <!--
# \begin{enumerate}
#
# \item \ce{SeF6}: \quad
# \chemfig{Se
#          (-[:0]\charge{[circle]90=\:,0=\:,270=\:}{F})
#          (-[:60]\charge{[circle]150=\:,60=\:,330=\:}{F})
#          (-[:120]\charge{[circle]210=\:,120=\:,30=\:}{F})
#          (-[:180]\charge{[circle]270=\:,180=\:,90=\:}{F})
#          (-[:240]\charge{[circle]330=\:,240=\:,150=\:}{F})
#          (-[:300]\charge{[circle]30=\:,300=\:,210=\:}{F})}
#
# \item \ce{XeF4}: \quad
# \chemfig{\charge{[circle]45=\:,225=\:}{Xe}
#     (-[:0]\charge{[circle]-90=\:,0=\:,90=\:}{F})
#     (-[:90]\charge{[circle]0=\:,180=\:,90=\:}{F})
#     (-[:180]\charge{[circle]-90=\:,180=\:,90=\:}{F})
#     (-[:270]\charge{[circle]-90=\:,180=\:,0=\:}{F})}
#
# \item \ce{SeCl3^{+}}: \quad
# $\left[\;
# \chemfig{\charge{[circle]270=\:}{Se}
#     (-[:0]\charge{[circle]-90=\:,0=\:,90=\:}{Cl})
#     (-[:90]\charge{[circle]0=\:,180=\:,90=\:}{Cl})
#     (-[:180]\charge{[circle]-90=\:,180=\:,90=\:}{Cl})}
# \;\right]^{+}$
#
# \item \ce{Cl2BBCl2}: (contains a B–B bond) \\[2ex]
# \chemfig{B
#          (-[:120]\charge{[circle]0=\:,90=\:,180=\:}{Cl})
#          (=[:240]\charge{[circle]0=\:,180=\:}{Cl}) -
#          B
#          (=[:60]\charge{[circle]0=\:,180=\:}{Cl})
#          (-[:300]\charge{[circle]0=\:,-90=\:,180=\:}{Cl}) }
#
# \end{enumerate}
#  -->
# ![image.png](attachment:ed8d7d14-f26b-451a-b440-348ff0d9b695.png)
#
# ![image.png](attachment:6edd6841-37e3-461f-8dfc-573ddfcabbac.png)
#
# <strong style="color:red">Oops</strong> I got (d) wrong.  Book answer was like
#
# ![image.png](attachment:f4fac3b6-5470-4218-ab53-d3f694b76631.png)

# %% [markdown]
# ### Exercise 7.33
# Correct the following statement:
# > The bonds in solid $\ce{PbCl2}$ are ionic; the bond in a HCl molecule is covalent. Thus, all of the valence electrons in $\ce{PbCl2}$ are located on the $\ce{Cl-}$ ions, and all of the valence electrons in a HCl molecule are shared between the H and Cl atoms.

# %% [markdown]
# Here is my correction:
# > The bonds in solid $\ce{PbCl2}$ are ionic; the bond in a HCl molecule is covalent. Thus, **2** of the **Pb** valence electrons in $\ce{PbCl2}$ are located on the $\ce{Cl-}$ ions, and **2** of the valence electrons in a HCl molecule are shared between the H and Cl atoms.
#
# <strong style="color:red">Oops:</strong> I should have said 2 of the Pb electrons per Pb atom.  I maybe should also have said transferred, not located.
#
# **But**, I'm not sure $\ce{PbCl2}$ is ionic because the difference in electronegativities is well under 1.8.  Pb is 1.9, Cl is 3.0, difference is 1.1, in which case my correction would have been this, but wikipedia sounds like $\ce{PbCl2}$ is indeed ionic:
# > The bonds in solid $\ce{PbCl2}$ are covalent; the bond in a HCl molecule is covalent also. Thus, **2** of the **Pb** valence electrons in $\ce{PbCl2}$ are **shared with the Cl atoms.** and **2** of the valence electrons in a HCl molecule are shared between the H and Cl atoms.

# %% [markdown]
# ### Exercise 7.35
# Methanol, $\ce{H3COH}$, is used as the fuel in some race cars. Ethanol, $\ce{C2H5OH}$, is used extensively as motor fuel in Brazil. Both methanol and ethanol produce $\ce{CO2}$ and $\ce{H2O}$ when they burn. Write the chemical equations for these combustion reactions using Lewis structures instead of chemical formulas.

# %%
meth_val_e = 3*1 + 4 + 6 + 1
eth_val_e = 2*4 + 5*1 + 6 + 1
display(meth_val_e, eth_val_e)
# Out:
# 14
# 20

# %% [markdown]
# <!--
# \begin{itemize}
# \item \;
# \ce{2 H3COH + 3 O2 -> 2 CO2 + 4 H2O } \\[1ex]
# \ce{
#     \large{2} $\left[
# \chemname{\chemfig{
#         C
#         (-[:90]H)
#         (-[:180]H)
#         (-[:270]H)
#         - \charge{[circle]90=\:,-90=\:}{O}
#         - H
# }}{methanol \ce{H3COH}}
#       \right]$
#   + 3 $\left[
# \chemname{\chemfig{
#         \charge{[circle]90=\:,-90=\:}{O}
#         = \charge{[circle]90=\:,-90=\:}{O}
# }}{\ce{O2}}
#       \right]$
#  -> 2 $\left[
# \chemname{\chemfig{
#         \charge{[circle]-90=\:,90=\:}{O}
#         = C
#         = \charge{[circle]-90=\:,90=\:}{O}
# }}{\ce{CO2}}
#       \right]$
#   + 4 $\left[
# \chemname{\chemfig{
#         H
#         -\charge{[circle]0=\:,90=\:}{O}
#         -[:-90]H
# }}{\ce{H2O}}
#       \;\right]$
#    }
# \item \;
# \ce{C2H5OH + 3 O2 -> 2 CO2 + 3 H2O } \\[1ex]
# \ce{
#     $\left[
# \chemname{\chemfig{
#         C
#         (-[:90]H)
#         (-[:180]H)
#         (-[:270]H)
#         - C
#         (-[:90]H)
#         (-[:270]H)
#         - \charge{[circle]90=\:,-90=\:}{O}
#         - H
# }}{ethanol \ce{C2H5OH}}
#     \right]$
#     + 3 $\left[
# \chemname{\chemfig{
#         \charge{[circle]90=\:,-90=\:}{O}
#         = \charge{[circle]90=\:,-90=\:}{O}
# }}{\ce{O2}}
#     \right]$
#     -> 2 $\left[
# \chemname{\chemfig{
#         \charge{[circle]-90=\:,90=\:}{O}
#         = C
#         = \charge{[circle]-90=\:,90=\:}{O}
# }}{\ce{CO2}}
#     \right]$
#     + 3 $\left[
# \chemname{\chemfig{
#         H
#         -\charge{[circle]0=\:,90=\:}{O}
#         -[:-90]H
# }}{\ce{H2O}}
#     \;\right]$
# }
#
# \end{itemize}
#  -->
#
# ![image.png](attachment:89cea9ff-4932-4d13-8a45-87559c3d8bcd.png)
#
# ![image.png](attachment:01ec7668-4e65-412e-a7e0-5d9c5fd74add.png)
#
# Wow, book answer basically looked the same but didn't use brackets.

# %% [markdown]
# ### Exercise 7.37
# Carbon tetrachloride was formerly used in fire extinguishers for electrical fires. It is no longer used for this purpose because of the formation of the toxic gas phosgene, $\ce{Cl2CO}$. Write the Lewis structures for carbon tetrachloride and phosgene.

# %% [markdown]
# <!--
# \begin{itemize}
#     \item \ce{CCl4} \quad
# \chemfig{C
#     (-[:0]\charge{[circle]-90=\:,0=\:,90=\:}{Cl})
#     (-[:90]\charge{[circle]0=\:,180=\:,90=\:}{Cl})
#     (-[:180]\charge{[circle]-90=\:,180=\:,90=\:}{Cl})
#     (-[:270]\charge{[circle]-90=\:,180=\:,0=\:}{Cl})}
#
#     \item \ce{Cl2CO} \quad
# \chemfig{C
#     (-[:90]\charge{[circle]180=\:,90=\:,0=\:}{Cl})
#     (-[:270]\charge{[circle]180=\:,-90=\:,0=\:}{Cl})
#     - \charge{[circle]90=\:,0=\:,270=\:}{O}}
#
# \end{itemize}
#  -->
#
# ![image.png](attachment:315e2eb3-334a-49cb-a057-8b112bea303f.png)
#
# ![image.png](attachment:0a0ae763-5417-4bc0-87ec-60c76ff552bd.png)
#
# <strong style="color:red">Oops:</strong> I didn't make an octet on the carbon in phosgene.  Book answer has a double bond:
#
# ![image.png](attachment:0b72b9d9-7a3f-405a-99d6-7ea2bf101595.png)

# %% [markdown]
# ### Example 7.39
# The arrangement of atoms in several biologically important molecules is given here. Complete the Lewis structures of these molecules by adding multiple bonds and lone pairs. Do not add any more atoms.
#
# (a) the amino acid serine:
#
# ![image.png](attachment:1d54fa53-17c7-48ef-b004-063ecb74e524.png)
#
# (b) urea:
#
# ![image.png](attachment:e145e72b-b66f-4e85-8ad6-bd85142e776a.png)
#
# (c) pyruvic acid:
#
# ![image.png](attachment:5c8c0697-fa3f-4bb4-b876-2a8f03fcd940.png)
#
# (d) uracil:
#
# ![image.png](attachment:91ff327a-a107-4073-93ca-7aabbda7cd72.png)
#
# (e) carbonic acid:
#
# ![image.png](attachment:e4f2f77e-92ee-498c-8301-6ded92679917.png)

# %%
# valence electrons, and remaining valence electrons after single bonds.
av = 7*1 + 1*5 + 3*4 + 3*6
arv = av - 2*13
display("a", av, arv)
bv = 4*1 + 2*5 + 1*4 + 1*6
brv = bv - 2*7
display("b", bv, brv)
cv = 4*1 + 3*4 + 3*6
crv = cv - 2*9
display("c", cv, crv)
dv = 4*4 + 2*5 + 2*6 + 4*1
drv = dv - 2*12
display("d", dv, drv)
ev = 2*1 + 3*6 + 1*4
erv = ev - 2*5
display("e", ev, erv)
# Out:
# 'a'
# 42
# 16
# 'b'
# 24
# 10
# 'c'
# 34
# 16
# 'd'
# 42
# 18
# 'e'
# 24
# 14

# %% [markdown]
# <!--
# \begin{enumerate}
#
# %\setchemfig{atom sep=2em} %default 3em
#
# \item the amino acid serine: 42 $e^-$, 16 after single bonds \quad \\[2ex]
# \chemfig{
# H
# -N (-[:90]H)
# -C (-[:-90]H) (-[:90,2]C (-[:180]H) (-[:0]H) -[:90]O - H)
# -C (-[:90]O)
# -O
# -H
# }
# \qquad
# \chemfig{
#     H
#     -\charge{[circle]-90=\:}{N} (-[:90]H)
#     -C (-[:-90]H) (-[:90,2]C (-[:180]H) (-[:0]H)
#         -[:90]\charge{[circle]180=\:,90=\:}{O} - H)
#     -C (=[:90]\charge{[circle]180=\:,0=\:}{O})
#     -\charge{[circle]90=\:,-90=\:}{O}
#     -H
# }
#
# \item urea: 24 $e^-$, 10 after single bonds \quad \\[2ex]
#
# \chemfig{
# H
# -N (-[:90]H)
# -C (-[:90]O)
# -N (-[:90]H)
# -H
# }
# \qquad
# \chemfig{
#     H
#     -\charge{[circle]-90=\:}{N} (-[:90]H)
#     -C (=[:90]\charge{[circle]180=\:,0=\:}{O})
#     -\charge{[circle]-90=\:}{N} (-[:90]H)
#     -H
# }
#
# \item pyruvic acid: 34 $e^-$, 16 after single bonds \quad \\[2ex]
#
# \chemfig{
# H
# -C (-[:90]H) (-[:-90]H)
# -C (-[:90]O)
# -C (-[:90]O)
# -O
# -H
# }
# \qquad
# \chemfig{
#     H
#     -C (-[:90]H) (-[:-90]H)
#     -C (=[:90]\charge{[circle]180=\:,0=\:}{O})
#     -C (=[:90]\charge{[circle]180=\:,0=\:}{O})
#     -\charge{[circle]90=\:,-90=\:}{O}
#     -H
# }
#
# \item uracil: 42 $e^-$, 18 after single bonds \quad \\[2ex]
#
# \chemfig{
# C*6( (-O)
# -N (-H)
# -C (-H)
# -C (-H)
# -C (-O)
# -N (-H)
# -)
# }
# \qquad
# \chemfig{
# C*6( (=\charge{[circle]120=\:,300=\:}{O})
# -\charge{[circle]330=\:}{N} (-H)
# -C (-H)
# =C (-H)
# -C (=\charge{[circle]180=\:,0=\:}{O})
# -\charge{[circle]330=\:}{N} (-H)
# -)
# }
#
# \item carbonic acid: 24 $e^-$, 14 after single bonds \quad \\[2ex]
#
# \chemfig{
# H
# -O
# -C (-[:90]O)
# -O
# -H
# }
# \qquad
# \chemfig{
#     H
#     -\charge{[circle]-90=\:,90=\:}{O}
#     -C (=[:90]\charge{[circle]180=\:,0=\:}{O})
#     -\charge{[circle]-90=\:,90=\:}{O}
#     -H
# }
# \end{enumerate}
#  -->
# ![image.png](attachment:0bf89868-e451-4634-a440-2067c98bb754.png)
#
# ![image.png](attachment:610218bf-a8fc-47d0-910b-2f5fef70c5df.png)
#
# ![image.png](attachment:187348dc-f725-4036-98d5-d88e84870bae.png)
#
# ![image.png](attachment:bbee45ff-9fc0-4574-ba3d-15b13d79cea5.png)
#
# ![image.png](attachment:fbb24908-37b8-4dd4-8c26-f0fed65b201d.png)
#
# ![image.png](attachment:8636a6a3-c8db-4f36-86c1-88d901467abd.png)
#
# Wow.  Kind of surprising I actually pulled that one out.

# %% [markdown]
# ### Example 7.41
# A compound with a molar mass of about 42 g/mol contains 85.7% carbon and 14.3% hydrogen by mass. Write the Lewis structure for a molecule of the compound.

# %%
from dp import *
def ex7_41(s):
    with localcontext(prec=6):
        mm = Decimal('42')
        mm_c = mm * Decimal('.857')
        mm_h = mm * Decimal('.143')
        num_c = mm_c / s.C
        num_h = mm_h / s.H
        v_e = 3*4 + 6*1
        return {
            'mm': mm,
            'mm C': mm_c,
            'mm H': mm_h,
            'num C': num_c,
            'num H': num_h,
            'val e-': v_e,
        }
ex7_41(b)
# Out:
# {'mm': Decimal('42'),
#  'mm C': Decimal('35.994'),
#  'mm H': Decimal('6.006'),
#  'num C': Decimal('2.99700'),
#  'num H': Decimal('5.95833'),
#  'val e-': 18}

# %% [markdown]
# So it looks like the molecular formula is $\ce{C3H6}$.
#
# That would have 18 valence electrons.
#
# <!--
# \chemfig{
#     C (-[:90]H) (-[:180]H) (-[:-90]H)
#     -C (-[:90]H)
#     =C (-[:90]H) (-[:0]H)
# }
#  -->
# ![image.png](attachment:07d98a30-c5a2-4368-bcb4-9cf2343e91eb.png)

# %% [markdown]
# ### Exercise 7.43
# How are single, double, and triple bonds similar? How do they differ?

# %% [markdown]
# Single, double, and triple bonds are all covalent bonds.  They all involve sharing electrons between two atoms.  They all occupy only one electron region per bond when using VSEPR to determine electron pair geometry and molecular structure.  They differ in the number of electrons shared, 2 for single, 4 for double, and 6 for triple.  They differ in the number of electrons they therefore contribute to making a full valence shell in the octet rule.  Finally, they differ in length and bond strength, with the multiple bonds being shorter and stronger and therefore taking more energy to break.
